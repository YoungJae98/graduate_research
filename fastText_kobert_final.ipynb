# %%
import pandas as pd
import urllib.request
from gensim.models.fasttext import FastText
from konlpy.tag import Okt
import numpy as np

# %%
train_data = pd.read_csv("data.csv", header=None)
label_data = pd.read_csv("data2.csv", header=None)

# %%
#결측값 제거
train_data = train_data.dropna(how = 'any')

#필요없는 단일문자 제거
for i in range(len(train_data)):
    train_data.iloc[i] = train_data.iloc[i].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# Out:
# False

# %%
#학습이 가능하도록 데이터 정리
new_train = []
for i in train_data:
    if i == 0:
        continue
    for j in train_data[i]:
        new_train.append(j)

train = pd.DataFrame(new_train)

# %%
#불용어 설정
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','을','를','으로','자','에','와','한','하다']

# %%
#Okt 패키지를 이용해서 각 문장을 토큰화하고 불용어를 제거
okt = Okt()
tokenized_data = []
for sentence in train[0]:
    temp_X = okt.morphs(sentence, stem=True) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    tokenized_data.append(temp_X)

# %%
#벡터값의 비교를 위해서 gensim의 fastText를 이용해서 학습해두기
model = FastText(tokenized_data, vector_size=300, window=5, min_count=5, workers=4, sg=1)

# %%
#단어들에 대해 유사어를 정렬하기 위해서 FastText에서 벡터화된 단어들 뽑아내기
vocab = list(model.wv.index_to_key)

#단어들 벡터 뽑아내기
X = model.wv[vocab]

# %%
#길이가 1인 단어들 제거하기
for j in range(10):
    for i in vocab:
        length = len(i.replace(' ', ''))
        if(length == 1):
            vocab.remove(i)

# %%
#각 단어들의 빈도수 체크하기
vocab_count = []

for i in range(len(vocab)):
    cnt = 0 
    for j in tokenized_data:
        cnt += j.count(vocab[i])
    vocab_count.append(cnt)

#상위 100개 단어들 뽑기
top_vocab = vocab[:100]
len(top_vocab)
# Out:
# 100

# %%
#fastText에서 빈도수 top100에 대한 유사어 정리
result_fastText = {}
for i in top_vocab:
    sim = []
    for j in range(10):
        sim.append(model.wv.most_similar(i)[j][0])
    result_fastText[i] = sim

# %%
#결과물
result_fastText
# Out:
# {'있다': ['생기', '깨지다', '발생', '중요하다', '이라는', '쌓이다', '부족하다', '전화하다', '인하다', '볼'],
#  '않다': ['상대', '맞다', '설득', '유리하다', '고통', '다르다', '원하다', '하지만', '상대방', '피해'],
#  '생각': ['웬만하다', '만약', '나르다', '산만하다', '주장', '나쁘다', '이야기', '왠만하다', '마음', '잘해주다'],
#  '사람': ['다른', '믿다', '주변', '다르다', '고통', '굽히다', '라고', '인정', '공감', '사귀다'],
#  '같다': ['없다', '적다', '딱하다', '건', '그렇다', '구분', '느낌', '아무', '막', '상상'],
#  '되다': ['인하다', '도움', '아무', '잘못', '이유', '어쩔', '당하다', '어렵다', '딱하다', '무엇'],
#  '없다': ['적다', '딱하다', '아무', '때문', '당연하다', '어쩔', '경험', '전혀', '혼동', '당하다'],
#  '보다': ['들어가다', '어리다', '글', '즐기다', '잠', '장문', '써다', '아침', '월', '카페'],
#  '그렇다': ['그렇게', '아니다', '막', '그렇다고', '별로', '라는', '딱하다', '그런', '이렇게', '싫다'],
#  '하고': ['대화', '사과', '통해', '후', '해결', '풀다', '불구', '기다', '다툼', '다음'],
#  '에서': ['부터', '대학교', '고등학교', '대학', '중학교', '초등학교', '팀', '반', '동료', '졸업'],
#  '들다': ['들어서다', '어떻다', '즉흥', '그림', '기분', '구체', '감', '듯', '거들다', '인가요'],
#  '친구': ['중학교', '두', '친하다', '고등학교', '지내다', '다니다', '랑', '처음', '학교', '언니'],
#  '아니다': ['그렇게', '막', '그렇다', '그렇다고', '그런', '정말', '싶다', '별로', '아무', '이렇게'],
#  '시간': ['보내다', '공부', '책', '하루', '읽다', '간', '시험', '준비', '운동', '영화'],
#  '이다': ['이라', '대인관계', '란', '어렵다', '에는', '대인', '중요하다', '인하다', '사이', '성격'],
#  '경우': ['원하다', '크게', '하지만', '라면', '이라고', '때문', '양보', '결과', '강하다', '다수'],
#  '자다': ['성격', '비슷하다', '위로', '싶다', '펴다', '해도', '불편하다', '욕', '통', '힘들다'],
#  '에게': ['않다', '자신', '상대', '상대방', '나', '방식', '피해', '다른', '남', '고통'],
#  '의견': ['상대방', '이해', '상대', '피', '따르다', '고통', '다르다', '원하다', '옳다', '설득'],
#  '많이': ['바로', '로는', '라서', '그리고', '드러나다', '또', '그게', '체적', '동', '애기'],
#  '다른': ['주변', '믿다', '사람', '다르다', '고통', '라고', '굽히다', '이라고', '주장', '판단'],
#  '좋다': ['약간', '뭔가', '라는', '처럼', '진짜', '식', '정해지다', '이런', '어떻다', '우울하다'],
#  '행동': ['방식', '남', '보통', '기분', '스스로', '강하다', '유리하다', '옳다', '지는', '설명'],
#  '편이': ['듭니', '맞추다', '경계', '니', '따르다', '기존', '그날', '몸', '존중', '참다'],
#  '많다': ['지속', '성향', '기본', '드러내다', '요청', '낼', '반복', '일반', '금전', '그건'],
#  '때문': ['딱하다', '이기', '싫어하다', '당하다', '의미', '야하다', '변하다', '그러하다', '경험', '아무'],
#  '이야기': ['공감', '일단', '대부분', '다른사람', '주장', '대로', '존중', '다만', '산만하다', '칭찬'],
#  '노력': ['최대한', '맞추다', '달성', '선', '포기', '이익', '위', '설득', '목적', '우선'],
#  '어떻다': ['뭔가', '라는', '느낌', '우울하다', '이런', '질문', '만들다', '들어서다', '뭔', '라든가'],
#  '이나': ['서다', '목적', '우선', '능력', '자신', '사실', '거부', '끄다', '보여주다', '타인'],
#  '에는': ['순간', '이유', '대치', '뿐', '쌓이다', '옛날', '윗', '거의', '전화하다', '겪다'],
#  '느끼다': ['크다', '흥미', '매사', '감', '편', '스스로', '표현', '감정', '보통', '듯'],
#  '편입': ['다', '세우다', '계획', '맞추다', '니', '듭니', '편이', '그날', '따르다', '몸'],
#  '좋아하다': ['분명하다', '수학', '처럼', '과목', '즉흥', '미술', '정해지다', '이러하다', '내용', '선택'],
#  '관계': ['유지', '신뢰', '서로', '어렵다', '시작', '지인', '과의', '되어다', '대인관계', '이다'],
#  '상황': ['잘못', '발생', '판단', '대한', '생기', '사실', '생기다', '시키다', '거짓말', '입장'],
#  '가다': ['술', '음식', '먹다', '여행', '나가다', '걸리다', '회사', '밥', '보다', '오래'],
#  '그냥': ['이렇게', '너', '막', '네', '식', '안', '싶다', '아', '이렇다', '아니다'],
#  '받다': ['인정받다', '능력', '도움', '진가', '에게는', '에게도', '사실', '대한', '만큼', '스트레스'],
#  '감정': ['부정', '긍정', '표현', '인', '개인', '실용', '실리', '창조', '세부', '성적'],
#  '하지만': ['다수', '대로', '받아들이다', '결정', '다만', '대부분', '주장', '크게', '피해', '양보'],
#  '얘기': ['안', '예요', '너', '마음', '그냥', '또', '제', '식', '한테', '자기'],
#  '해주다': ['공감', '주다', '다르다', '이야기', '고통', '잘해주다', '듣다', '나르다', '다른사람', '옳다'],
#  '맞다': ['않다', '다르다', '유리하다', '상대', '주장', '나르다', '옳다', '설득', '웬만하다', '일단'],
#  '일이': ['어쩔', '별', '전혀', '부족하다', '아무', '지다', '당연하다', '보이다', '건지다', '전화하다'],
#  '대해': ['부분', '통해', '사실', '생기다', '대한', '상황', '이익', '갈등', '시키다', '발생'],
#  '되어다': ['시작', '함께', '동료', '직원', '고등학교', '팀', '친해지다', '오랜', '사이', '지나다'],
#  '위해': ['노력', '대해', '이익', '하고', '해결', '대화', '통해', '목적', '설득', '달성'],
#  '경험': ['구분', '적다', '혼동', '때문', '의미', '이기', '상상', '딱하다', '없다', '쓸모없다'],
#  '상대방': ['상대', '따르다', '의견', '옳다', '최대한', '고통', '관습', '이해', '피', '않다'],
#  '정도': ['어느', '명', '자주', '만나다', '과의', '연락', '지인', '달', '가족', '매일'],
#  '싶다': ['해도', '얘', '이르다', '펴다', '그걸', '땐', '정말', '야', '취향', '되게'],
#  '이렇다': ['뭐', '이렇게', '네', '약간', '막', '거', '그냥', '너', '걸', '근데'],
#  '그렇게': ['그렇다', '아니다', '왜', '막', '이렇게', '저', '그렇다고', '정말', '그런', '아무'],
#  '지금': ['그런데', '애', '이랑', '곳', '남자친구', '그때', '엄마', '근데', '엄청', '그래서'],
#  '이고': ['실리', '예술', '창조', '활동', '철학', '추상', '실용', '인', '부정', '긍정'],
#  '연락': ['명', '정도', '만나다', '회', '지내다', '두', '자주', '어느', '달', '직장'],
#  '부분': ['양보', '결과', '발생', '충분하다', '찾다', '라면', '대한', '상황', '얻다', '또한'],
#  '같이': ['고등학교', '초등학교', '팀', '중학교', '부터', '대학', '엄마', '졸업', '반', '친해지다'],
#  '서로': ['유지', '시작', '되어다', '관계', '함께', '지인', '다시', '점', '어렵다', '고민'],
#  '너무': ['야', '얘', '이르다', '되게', '치다', '아빠', '돌아오다', '고맙다', '어', '그걸'],
#  '문제': ['답', '관련', '수학', '여유', '정해지다', '과목', '주어지다', '시험', '분명하다', '처럼'],
#  '만나다': ['처음', '달', '지내다', '두', '매일', '가족', '오다', '명', '다니다', '자주'],
#  '까지': ['이후', '다시', '고민', '분', '달', '자리', '옆', '상사', '일주일', '전화'],
#  '먼저': ['들어주다', '며', '터', '존중', '피', '수용', '다르다', '듭니', '피하', '사과'],
#  '그래서': ['그런데', '살다', '근데', '니까', '애', '항상', '죠', '거의', '지금', '그거'],
#  '주변': ['믿다', '다른', '사람', '고통', '다르다', '이해', '공감', '남', '인정', '에게'],
#  '해보다': ['확인', '어떻', '무슨', '여러', '어', '부모님', '보기', '원인', '가보다', '건강'],
#  '신뢰': ['어렵다', '대인관계', '관계', '유지', '이다', '중요하다', '인하다', '란', '이라', '서로'],
#  '먹다': ['밥', '음식', '가다', '술', '집', '말다', '보다', '오다', '보내다', '운동'],
#  '힘들다': ['걸다', '거짓말', '해도', '거짓', '실수', '배려', '통', '조언', '마다', '대다'],
#  '관심': ['끄다', '인정받다', '인정', '사귀다', '이익', '받다', '진가', '판단', '다른', '사실'],
#  '원하다': ['경우', '상대', '고통', '라면', '하지만', '옳다', '크게', '이라고', '강하다', '설득'],
#  '이해': ['고통', '공감', '다르다', '피', '상대', '인정', '상대방', '존중', '의견', '선'],
#  '어렵다': ['대인관계', '인하다', '란', '중요하다', '점', '신뢰', '이라', '대인', '이다', '어쩔'],
#  '크다': ['느끼다', '흥미', '매사', '감', '스스로', '편', '크게', '별로', '그러하다', '이러하다'],
#  '거나': ['지만', '지는', '관습', '일단', '겉', '그러나', '기존', '최대한', '상대방', '에게'],
#  '마음': ['든', '펴다', '까지는', '걔', '조금', '통', '드리다', '자기', '틀리다', '대답'],
#  '나다': ['엄청', '애', '그런데', '이랑', '그때', '남자친구', '치다', '죠', '너무', '아빠'],
#  '직장': ['동료', '회사', '다시', '달', '매일', '두', '분', '시작', '처음', '지내다'],
#  '자주': ['매일', '가족', '일주일', '새롭다', '전화', '거리', '달', '과는', '한번', '세'],
#  '나오다': ['치다', '이건', '건지다', '빠져나오다', '완전', '버리다', '안좋다', '재밌다', '죠', '예전'],
#  '모르다': ['정말', '해도', '안되다', '줄', '이르다', '싶다', '그거', '얘', '땐', '이유'],
#  '자신': ['피해', '사실', '유리하다', '칭찬', '타인', '누군가', '나쁘다', '주지', '고통스럽다', '손해'],
#  '지내다': ['두', '년', '만나다', '친하다', '직장', '처음', '몇', '명', '다시', '달'],
#  '업무': ['수행', '및', '남다', '전체', '요구', '정해진', '도출', '자료', '계산', '적극'],
#  '그리고': ['만약', '앞서', '일화', '고르다', '애기', '목소리', '하나요', '후회', '바로', '빠르다'],
#  '주다': ['잘해주다', '나르다', '주지', '거짓말', '에게도', '별다르다', '위로', '사실', '조언', '칭찬'],
#  '라고': ['비슷하다', '불편하다', '나르다', '아무', '이유', '편하다', '성격', '웬만하다', '굽히다', '굳이'],
#  '표현': ['그대로', '표', '앞서다', '스스로', '보다는', '기분', '성적', '듯', '보통', '매사'],
#  '흥미': ['느끼다', '크다', '매사', '편', '못', '감', '스스로', '크게', '보통', '별로'],
#  '걱정': ['미래', '건강', '그거', '항상', '가면', '즐겁다', '잠깐', '보기', '여기', '건데'],
#  '따르다': ['옳다', '맞추다', '관습', '상대방', '피', '기존', '최대한', '력', '존중', '고통'],
#  '기분': ['듯', '말로', '스스로', '설명', '표정', '앞서다', '본인', '개인', '한다는', '싫다'],
#  '한테': ['너', '이렇게', '랑', '네', '언니', '막', '남자친구', '나다', '근데', '싶다'],
#  '믿다': ['주변', '다른', '사람', '고통', '남', '않다', '이해', '라고', '인정', '다르다'],
#  '읽다': ['책', '글', '보내다', '준비', '영화', '하루', '운동', '간', '공부', '보다'],
#  '해결': ['이루다', '통해', '찾기', '대화', '과정', '풀다', '하고', '여', '찾다', '여러'],
#  '가끔': ['아빠', '재밌다', '어', '버리다', '완전', '야', '잠깐', '이건', '이니까', '교수']}

# %%
#Bert 모델 불러오고 pretrained 모델 가져오기
from kobert_tokenizer import KoBERTTokenizer
import torch
from transformers import BertModel

model_bert = BertModel.from_pretrained('skt/kobert-base-v1')
tokenizer = KoBERTTokenizer.from_pretrained('skt/kobert-base-v1', sp_model_kwargs={'nbest_size': -1, 'alpha': 0.6, 'enable_sampling': True})
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'XLNetTokenizer'.
# The class this function is called from is 'KoBERTTokenizer'.

# %%
#기존에 토큰화된 데이터 옯기고
tokenized_data_bert = tokenized_data

#각 데이터 앞뒤에 시작, 종료를 나타내는 심볼 추가하기
for i in tokenized_data_bert:
    i.insert(0, '[CLS]')
    i.append('[SEP]')

# %%
#한글자까지 전부 포함해서 뽑고
#두글자 top100에서 유사한 단어 뽑아보기 -> vocab 재정의 필요 -> fastText에서도 한글자는 이용되긴 함
vocab_new = list(model.wv.index_to_key)     
result_bert = {}
for i in vocab_new:
    result_bert[i] = torch.FloatTensor([0] * 768)
    
#갯수용 딕셔너리
result_cnt = {}
for i in vocab_new:
    result_cnt[i] = 0

for sentence in tokenized_data_bert:
    indexed_text = torch.tensor([tokenizer.convert_tokens_to_ids(sentence)])
    segments_ids = torch.tensor([[1] * len(sentence)])
    
    model_bert.eval()
    
    encoded_layers = model_bert(indexed_text, segments_ids)
    embedded_layer = encoded_layers.last_hidden_state.squeeze()
    
    #각 단어에 해당하는 딕셔너리에서 값 갱신 필요 -> 평균을 구해야함 not 갱신
    #총 몇개로 나누어야하는지가 문제 -> 갯수용 딕셔너리를 추가하고 값을 더하는 방식으로 수정
    #결과 다 끝난 후 갯수로 나누어주기
    #vocab에서 사라지는 단어들도 있는 이슈 발생 -> 1. tokenized 합치고 unique로 vocab뽑기 2. 의미없는거니까 그냥 무시하기
    #2번으로 일단 해보기
    for i, ch in enumerate(sentence):
        if ch in vocab_new:
            if ch == '[CLS]' or ch == '[SEP]': continue
            result_bert[ch] += embedded_layer[i].detach()
            result_cnt[ch] += 1

for i in result_bert:
    result_bert[i] = result_bert[i] / result_cnt[i]

# %%
for i in result_bert:
    print(i, result_bert[i][:5])
# Out:
# 있다 tensor([ 0.0077,  0.0510,  0.0230, -4.6489,  0.0991])
# 것 tensor([ 0.1466, -0.0625,  0.3126, -4.1251,  0.1827])
# 않다 tensor([ 0.0991, -0.1229,  0.2912, -4.9780,  0.1957])
# 생각 tensor([ 0.0593, -0.1169,  0.2582, -5.0332,  0.2160])
# 적 tensor([ 0.1664, -0.2066,  0.4020, -4.3611,  0.0487])
# 사람 tensor([-0.0330,  0.0664,  0.0989, -4.8229,  0.0231])
# 때 tensor([ 0.1537, -0.1033,  0.0459, -4.5065,  0.1500])
# 같다 tensor([ 0.0117, -0.1559,  0.2799, -4.9074,  0.2604])
# 되다 tensor([ 0.0870, -0.1323,  0.3060, -4.9139,  0.1916])
# 그 tensor([ 0.0978, -0.0975,  0.1517, -4.6501,  0.4160])
# 없다 tensor([ 0.0533, -0.1137,  0.2765, -5.0644,  0.1935])
# 내 tensor([ 0.0549,  0.0292,  0.0420, -4.5704,  0.2175])
# 보다 tensor([ 0.2768, -0.0892,  0.2543, -4.4140,  0.2092])
# 저 tensor([ 0.0093,  0.0546,  0.0456, -4.8837,  0.2115])
# 나 tensor([ 0.1177, -0.0903,  0.1574, -4.9111,  0.2580])
# 그렇다 tensor([ 0.0520, -0.1780,  0.2774, -4.6858,  0.1809])
# 다 tensor([ 0.0678, -0.0346,  0.2329, -5.0888,  0.2609])
# 일 tensor([ 0.1017,  0.0231,  0.2367, -5.4511,  0.1929])
# 제 tensor([ 0.0760, -0.0677,  0.2292, -5.2676,  0.2229])
# 인 tensor([-3.7052e-02,  4.3177e-03,  1.8210e-01, -4.4729e+00,  7.8337e-02])
# 하고 tensor([ 0.1240,  0.0160,  0.0157, -4.9302,  0.2254])
# 에서 tensor([ 0.1167, -0.0796,  0.1184, -5.5577,  0.2775])
# 들다 tensor([ 0.0603, -0.1420,  0.2423, -4.8959,  0.1980])
# 친구 tensor([ 0.0786, -0.1999,  0.2853, -4.6764,  0.1962])
# 아니다 tensor([ 0.0664, -0.1123,  0.2686, -4.9649,  0.2121])
# 수 tensor([ 0.2714, -0.0545,  0.1215, -5.0391,  0.0946])
# 못 tensor([ 0.1254,  0.0558, -0.0263, -4.9568,  0.1511])
# 시간 tensor([ 0.0451, -0.0590,  0.1152, -5.5838,  0.1859])
# 이다 tensor([ 0.1604,  0.0633,  0.2446, -5.3965,  0.2062])
# 로 tensor([ 0.1743,  0.0145,  0.1197, -5.3981,  0.1390])
# 경우 tensor([ 0.0836, -0.1590,  0.2981, -4.9739,  0.1936])
# 자다 tensor([ 0.0713, -0.1324,  0.2724, -4.9062,  0.1905])
# 말 tensor([ 0.0844,  0.0150,  0.2392, -4.8955,  0.1962])
# 에게 tensor([ 0.2009, -0.0995,  0.1613, -4.9299,  0.2045])
# 의견 tensor([ 0.0681, -0.0703,  0.2595, -5.2983,  0.2291])
# 많이 tensor([ 0.0963, -0.1427,  0.2800, -4.9358,  0.1851])
# 더 tensor([ 0.1367, -0.0328,  0.1391, -4.8443,  0.4180])
# 다른 tensor([ 0.0659, -0.0228,  0.1864, -5.0251,  0.2943])
# 좋다 tensor([ 0.0621, -0.1398,  0.2644, -4.9584,  0.2115])
# 행동 tensor([ 0.0663, -0.1294,  0.2548, -5.1022,  0.1884])
# 편이 tensor([ 0.0904, -0.1147,  0.2426, -5.0393,  0.0817])
# 많다 tensor([ 0.0602, -0.1379,  0.2760, -4.8425,  0.2032])
# 때문 tensor([ 0.0927, -0.1281,  0.2855, -4.8851,  0.1873])
# 이야기 tensor([ 0.1089, -0.1267,  0.2584, -5.0866,  0.1995])
# 노력 tensor([ 0.0662, -0.1182,  0.2572, -4.9903,  0.1797])
# 어떻다 tensor([ 0.0599, -0.1630,  0.2759, -4.7645,  0.2150])
# 고 tensor([ 0.0997,  0.0496,  0.0454, -4.6784,  0.1835])
# 이나 tensor([ 0.1169, -0.0090,  0.2445, -5.0342,  0.1555])
# 에는 tensor([ 0.1402, -0.0165,  0.1580, -5.7201,  0.2373])
# 니 tensor([-0.0485, -0.1096,  0.1395, -5.3462,  0.0558])
# 안 tensor([ 0.1760, -0.0928,  0.0764, -4.6652,  0.3986])
# 느끼다 tensor([ 0.0790, -0.1376,  0.2507, -5.0780,  0.1896])
# 게 tensor([ 0.1811, -0.0538,  0.1761, -4.2489,  0.2553])
# 거 tensor([ 0.1170, -0.0074,  0.1500, -4.3188,  0.3293])
# 편입 tensor([ 1.2816e-01, -2.4037e-01,  2.6240e-01, -5.3572e+00, -8.0470e-04])
# 좋아하다 tensor([ 0.0199, -0.1643,  0.2787, -4.9915,  0.2496])
# 관계 tensor([ 0.1629, -0.1088, -0.0551, -5.0034,  0.0456])
# 상황 tensor([ 0.0999, -0.0546,  0.1082, -6.0013,  0.1799])
# 가다 tensor([ 0.0739, -0.1583,  0.2752, -4.9590,  0.2002])
# 그냥 tensor([ 0.0448, -0.1580,  0.2768, -4.7571,  0.1851])
# 받다 tensor([ 0.1067, -0.1592,  0.2884, -4.7481,  0.1745])
# 감정 tensor([ 0.0521, -0.1479,  0.2535, -4.7737,  0.2065])
# 서 tensor([ 0.0366, -0.1778,  0.2739, -5.2028,  0.1758])
# 하지만 tensor([ 0.0815, -0.0059,  0.1259, -5.6826,  0.2564])
# 얘기 tensor([ 0.0749, -0.1570,  0.3032, -4.7308,  0.1975])
# 해주다 tensor([ 0.0594, -0.1477,  0.2741, -4.8348,  0.1783])
# 맞다 tensor([ 0.0683, -0.1159,  0.2924, -5.0196,  0.2246])
# 일이 tensor([ 0.1139, -0.1750,  0.2541, -5.0102,  0.1425])
# 대해 tensor([ 0.0480, -0.1708,  0.2820, -4.7668,  0.2172])
# 되어다 tensor([ 0.1005, -0.1139,  0.2759, -4.9287,  0.1974])
# 위해 tensor([ 0.0976, -0.1656,  0.2849, -4.9122,  0.1617])
# 경험 tensor([ 0.0706, -0.1811,  0.2509, -5.0188,  0.1352])
# 상대방 tensor([ 0.0731, -0.1022,  0.2772, -5.2080,  0.2469])
# 정도 tensor([-1.1501e-03, -1.1213e-01,  2.4721e-01, -4.8708e+00,  1.9786e-01])
# 싶다 tensor([ 0.0834, -0.1273,  0.2683, -4.8731,  0.1928])
# 하 tensor([ 0.0745, -0.1559, -0.1816, -4.8492, -0.0330])
# 이렇다 tensor([ 0.0423, -0.2272,  0.3048, -4.5120,  0.1493])
# 그렇게 tensor([ 0.0559, -0.1762,  0.3093, -4.7274,  0.2039])
# 지금 tensor([ 0.1376, -0.0126,  0.1056, -4.3990,  0.1777])
# 이고 tensor([ 0.0863, -0.1324,  0.2156, -4.5922,  0.1148])
# 연락 tensor([ 0.0393, -0.1554,  0.2778, -5.0541,  0.1887])
# 부분 tensor([ 0.0969, -0.1828,  0.2952, -4.8534,  0.1994])
# 같이 tensor([ 0.0895, -0.1556,  0.2903, -4.7776,  0.2093])
# 서로 tensor([ 0.0957, -0.1189,  0.2687, -4.9897,  0.2549])
# 너무 tensor([ 0.0909, -0.1256,  0.2730, -4.9083,  0.2505])
# 문제 tensor([ 0.1014, -0.0528,  0.0843, -5.0240,  0.1369])
# 편 tensor([ 0.1289,  0.1539,  0.2066, -5.3570,  0.0794])
# 만나다 tensor([ 0.0548, -0.1144,  0.2496, -4.9624,  0.2127])
# 만 tensor([ 0.2576,  0.0472,  0.1759, -4.9254,  0.2365])
# 예 tensor([ 0.0745, -0.1408,  0.1365, -4.9163,  0.1393])
# 까지 tensor([ 0.2078, -0.1038,  0.2774, -5.1120,  0.2173])
# 먼저 tensor([ 0.0803, -0.1095,  0.2900, -4.9909,  0.2228])
# 그래서 tensor([ 0.0600, -0.1724,  0.2966, -4.6291,  0.1778])
# 주변 tensor([-0.0862, -0.1999,  0.2096, -5.1618,  0.1731])
# 걸 tensor([ 0.2504, -0.0822,  0.2490, -4.6065,  0.3737])
# 요 tensor([ 0.1421, -0.2255,  0.3877, -4.4752,  0.2056])
# 해보다 tensor([ 0.0535, -0.1502,  0.3035, -4.7152,  0.1889])
# 신뢰 tensor([ 0.0393, -0.0945,  0.1965, -5.1360,  0.1813])
# 먹다 tensor([ 0.0825, -0.1818,  0.3223, -4.7915,  0.2256])
# 힘들다 tensor([ 0.0734, -0.1436,  0.2611, -4.8749,  0.1887])
# 관심 tensor([ 0.0511, -0.1181,  0.2881, -5.1109,  0.1646])
# 원하다 tensor([ 0.0389, -0.1439,  0.2519, -4.9195,  0.1981])
# 이해 tensor([ 0.0726, -0.1256,  0.2399, -4.9424,  0.2121])
# 어렵다 tensor([ 0.0866, -0.1749,  0.2552, -4.9741,  0.2203])
# 크다 tensor([ 0.0888, -0.1106,  0.2729, -5.0990,  0.2054])
# 거나 tensor([ 0.2451, -0.0058,  0.1566, -4.1653,  0.2143])
# 마음 tensor([ 0.0399, -0.0103,  0.1745, -5.8406,  0.1555])
# 나다 tensor([ 0.0948, -0.1092,  0.2707, -4.9979,  0.2237])
# 직장 tensor([ 0.0378, -0.1446,  0.2356, -5.2139,  0.2167])
# 자주 tensor([ 0.0650, -0.1357,  0.2739, -5.1981,  0.1765])
# 나오다 tensor([ 0.0693, -0.1466,  0.2703, -4.8714,  0.2107])
# 뭐 tensor([ 0.0149, -0.0568, -0.0635, -4.3229,  0.2076])
# 모르다 tensor([ 0.0833, -0.1541,  0.2835, -4.8048,  0.2257])
# 자신 tensor([ 0.0905, -0.1507,  0.2064, -4.8150,  0.1836])
# 지내다 tensor([ 0.0876, -0.1808,  0.2528, -4.8484,  0.1424])
# 업무 tensor([ 0.0101, -0.0749,  0.0876, -5.7129,  0.1492])
# 그리고 tensor([ 0.0617, -0.1386,  0.2848, -4.7217,  0.1834])
# 주다 tensor([ 0.0691, -0.1339,  0.2720, -4.9851,  0.1860])
# 라고 tensor([ 0.1953, -0.0493,  0.2190, -5.0903,  0.2611])
# 표현 tensor([ 0.0411, -0.1717,  0.2330, -4.9915,  0.2403])
# 흥미 tensor([ 0.1061, -0.0740,  0.2648, -5.2913,  0.1927])
# 걱정 tensor([ 0.0549, -0.1675,  0.2792, -5.0522,  0.1853])
# 따르다 tensor([ 0.0829, -0.1055,  0.2927, -5.2179,  0.1832])
# 등 tensor([ 0.1272,  0.0652,  0.0593, -4.8370,  0.0417])
# 기분 tensor([ 0.1134, -0.1059,  0.2767, -5.0295,  0.2242])
# 한테 tensor([ 0.2313, -0.0614,  0.1042, -5.0123,  0.1937])
# 믿다 tensor([ 0.0153, -0.0583,  0.2433, -5.2140,  0.1813])
# 읽다 tensor([ 0.0398, -0.1248,  0.2480, -5.1919,  0.2244])
# 해결 tensor([ 0.0784, -0.1208,  0.2904, -4.9915,  0.2063])
# 가끔 tensor([ 0.0721, -0.1243,  0.2528, -5.0946,  0.1818])
# 대한 tensor([ 0.1334, -0.0063,  0.1396, -5.9302,  0.3119])
# 인정 tensor([ 0.0279, -0.1236,  0.2819, -5.1920,  0.1394])
# 가지 tensor([ 0.2074, -0.1109,  0.1599, -5.1986,  0.1303])
# 해 tensor([-0.0147, -0.1950,  0.0908, -4.9473,  0.2062])
# 혼자 tensor([ 0.0596, -0.1726,  0.2904, -4.8841,  0.1624])
# 듣다 tensor([ 0.0923, -0.1119,  0.2553, -5.0898,  0.1724])
# 친하다 tensor([ 0.0973, -0.1148,  0.2918, -4.8247,  0.2058])
# 알 tensor([ 0.0543, -0.2183,  0.2357, -4.0197, -0.0299])
# 선호 tensor([ 0.0080, -0.1943,  0.2620, -5.0309,  0.2332])
# 면 tensor([ 0.2155, -0.0784,  0.1896, -5.4531,  0.0944])
# 회사 tensor([ 0.0109, -0.0906,  0.0935, -5.6772,  0.1524])
# 전 tensor([-0.0145, -0.0804,  0.3093, -5.6242,  0.1189])
# 정답 tensor([ 0.0779, -0.2049,  0.2480, -4.9842,  0.1666])
# 남 tensor([-0.0678, -0.0456,  0.2362, -5.5138,  0.1681])
# 이라고 tensor([ 0.1548,  0.0735,  0.2083, -4.9768,  0.2926])
# 하나 tensor([ 0.0382, -0.0438, -0.0699, -4.8562,  0.3649])
# 정말 tensor([ 0.0407, -0.1174,  0.2388, -5.1037,  0.2177])
# 가장 tensor([ 0.0547, -0.1065,  0.2834, -4.9771,  0.2134])
# 대화 tensor([ 0.0600, -0.1315,  0.2863, -5.0258,  0.1950])
# 활동 tensor([ 0.0546, -0.1902,  0.1430, -4.9394, -0.0062])
# 알다 tensor([ 0.0476, -0.1856,  0.3039, -4.6743,  0.2220])
# 오다 tensor([ 0.0772, -0.1408,  0.3080, -4.8306,  0.1899])
# 번 tensor([ 0.2603,  0.0914,  0.2461, -5.0226,  0.2741])
# 중요하다 tensor([ 0.0502, -0.1206,  0.2423, -4.9831,  0.1794])
# 왜 tensor([ 0.1258, -0.0753,  0.0764, -4.5311,  0.2740])
# 처음 tensor([ 0.0080,  0.0067,  0.0822, -5.1646,  0.1348])
# 갈등 tensor([ 0.0637, -0.1152,  0.2721, -5.0183,  0.2311])
# 성격 tensor([ 0.0955, -0.1234,  0.3045, -4.9250,  0.1531])
# 집 tensor([ 2.5328e-01,  4.2972e-02,  2.6481e-01, -5.2588e+00, -3.2245e-03])
# 맞추다 tensor([ 0.0428, -0.1330,  0.3065, -5.0106,  0.2163])
# 떨어지다 tensor([ 0.1032, -0.1292,  0.2836, -5.3855,  0.2638])
# 도움 tensor([ 0.0721, -0.1517,  0.2327, -4.8454,  0.2035])
# 보다는 tensor([ 0.2093,  0.0214,  0.2308, -5.9398,  0.2367])
# 계속 tensor([ 0.0859, -0.1506,  0.2761, -4.9432,  0.1980])
# 시작 tensor([ 0.1015, -0.1424,  0.2759, -4.7901,  0.2071])
# 항상 tensor([ 0.0268, -0.1081,  0.2694, -5.0811,  0.2113])
# 쓰다 tensor([ 0.0926, -0.1238,  0.2545, -4.9821,  0.1691])
# 계획 tensor([ 0.1145, -0.0433,  0.0335, -5.0173,  0.1625])
# 적다 tensor([ 0.0753, -0.1224,  0.3040, -4.9623,  0.1787])
# 보내다 tensor([ 0.0532, -0.1739,  0.2608, -4.9896,  0.1919])
# 후 tensor([ 0.1598, -0.0932,  0.0787, -5.0493,  0.2739])
# 약간 tensor([ 0.0583, -0.2086,  0.3447, -4.3015,  0.1656])
# 만들다 tensor([ 0.0776, -0.1535,  0.2813, -4.7069,  0.2003])
# 생기다 tensor([ 0.0582, -0.1328,  0.2953, -4.7882,  0.2572])
# 보고 tensor([ 0.2351, -0.0458,  0.2448, -5.1939,  0.1932])
# 그것 tensor([ 0.0807, -0.1425,  0.3056, -4.9123,  0.2345])
# 안되다 tensor([ 0.0830, -0.1222,  0.2734, -4.9764,  0.1470])
# 내다 tensor([-0.0202, -0.1106,  0.2094, -5.0968,  0.2121])
# 최대한 tensor([ 0.0684, -0.0621,  0.2665, -5.2158,  0.2166])
# 방식 tensor([ 0.0584,  0.1005,  0.1826, -6.3463,  0.1643])
# 부정 tensor([-0.0644, -0.3378,  0.1665, -4.2121,  0.3014])
# 부터 tensor([ 0.2780, -0.0588,  0.1507, -4.9865,  0.2997])
# 책 tensor([ 0.1385, -0.0526,  0.1968, -5.1977,  0.1305])
# 새롭다 tensor([-0.0337, -0.1712,  0.2779, -5.0624,  0.2143])
# 과제 tensor([ 0.0308, -0.1184,  0.2595, -5.1211,  0.2477])
# 유지 tensor([ 0.0444, -0.1620,  0.1905, -5.0464,  0.1626])
# 인데 tensor([ 0.1710,  0.0554,  0.2481, -5.3135,  0.2748])
# 집중 tensor([ 0.0266, -0.1451,  0.2148, -5.2907,  0.1870])
# 크게 tensor([ 0.0658, -0.1206,  0.2414, -5.1788,  0.1922])
# 상상 tensor([ 0.0692, -0.1199,  0.2506, -5.1304,  0.2365])
# 능력 tensor([ 0.0245, -0.0088,  0.0986, -5.9982,  0.0764])
# 공감 tensor([ 0.0938, -0.1177,  0.2602, -5.1973,  0.1989])
# 라면 tensor([ 0.1672,  0.0238,  0.1694, -5.8245,  0.2184])
# 조금 tensor([ 0.0642, -0.1607,  0.2762, -4.9871,  0.1682])
# 딱 tensor([ 0.1596, -0.0083,  0.2092, -5.5463,  0.4155])
# 목표 tensor([ 0.0766, -0.0477,  0.0539, -4.9152,  0.1962])
# 주로 tensor([ 0.0087, -0.1030,  0.2517, -5.3737,  0.2081])
# 다니다 tensor([ 0.0464, -0.1275,  0.2887, -4.9166,  0.2544])
# 한번 tensor([ 0.0788, -0.1382,  0.2825, -5.2106,  0.2342])
# 신경 tensor([ 0.0738, -0.1251,  0.2537, -5.1903,  0.2341])
# 뭔가 tensor([ 0.0359, -0.1715,  0.3210, -4.6981,  0.2002])
# 일단 tensor([ 3.7491e-04, -1.0557e-01,  2.7872e-01, -5.1213e+00,  2.1576e-01])
# 공부 tensor([ 0.0593, -0.1905,  0.2620, -4.8710,  0.1663])
# 상대 tensor([ 0.1089, -0.0936,  0.2968, -5.1269,  0.2536])
# 무엇 tensor([ 0.0449, -0.1607,  0.2333, -5.0616,  0.1814])
# 그때 tensor([ 0.0311, -0.1645,  0.2567, -4.7317,  0.2169])
# 경계 tensor([ 0.0783, -0.1083,  0.1718, -5.2682,  0.0951])
# 건 tensor([ 0.1263,  0.1469,  0.1031, -5.2325,  0.3692])
# 다르다 tensor([ 0.0786, -0.1103,  0.2722, -4.8466,  0.1860])
# 라는 tensor([ 0.0923, -0.0166,  0.2080, -5.8527,  0.2105])
# 명 tensor([-2.8580e-02, -3.7472e-02,  3.2778e-01, -5.5216e+00,  4.2991e-03])
# 지인 tensor([ 0.0748, -0.1203,  0.2767, -5.2251,  0.2038])
# 거의 tensor([ 0.0990, -0.1089,  0.2879, -4.9868,  0.1953])
# 관습 tensor([ 0.0597, -0.1498,  0.2976, -5.0141,  0.2080])
# 긍정 tensor([-0.1146, -0.3375,  0.1380, -4.3188,  0.3155])
# 보통 tensor([-0.0145, -0.1138,  0.2616, -5.1641,  0.2078])
# 없이 tensor([ 0.1872,  0.0057,  0.1583, -5.4545,  0.1901])
# 실제 tensor([ 0.0229, -0.0812,  0.2489, -4.8649,  0.1886])
# 이렇게 tensor([ 0.0695, -0.1841,  0.3004, -4.6831,  0.1842])
# 인지 tensor([ 0.1218,  0.0172,  0.1578, -5.2947,  0.1678])
# 몸 tensor([ 0.0462,  0.0694,  0.1860, -5.8904,  0.1071])
# 답 tensor([ 0.0714,  0.1074,  0.1238, -5.0842,  0.1915])
# 친해지다 tensor([ 0.0787, -0.1622,  0.3014, -4.7598,  0.2636])
# 기억 tensor([ 0.0646, -0.2298,  0.2254, -4.6753,  0.1397])
# 결국 tensor([ 0.1033, -0.1418,  0.2453, -4.7635,  0.1673])
# 앞 tensor([ 0.1214,  0.0372,  0.1012, -5.2283,  0.2443])
# 다시 tensor([ 0.1198, -0.0920,  0.3032, -4.9474,  0.2518])
# 느낌 tensor([ 0.1016, -0.1378,  0.3461, -4.7175,  0.1974])
# 분 tensor([ 0.1386,  0.0398,  0.3048, -5.3380,  0.1350])
# 점 tensor([ 1.1361e-01, -5.3165e-04,  1.6172e-01, -6.0245e+00,  2.3504e-01])
# 식 tensor([ 0.0373, -0.1516,  0.4519, -5.2915,  0.1065])
# 어느 tensor([ 0.0756, -0.1362,  0.2619, -5.0393,  0.2146])
# 가족 tensor([ 0.0288, -0.0778,  0.1144, -6.0910,  0.1816])
# 별로 tensor([ 0.0946,  0.0411,  0.1766, -6.6339,  0.2085])
# 나가다 tensor([ 0.1226, -0.1725,  0.2661, -5.1469,  0.2141])
# 고민 tensor([ 0.0875, -0.1478,  0.2135, -4.8395,  0.1939])
# 중 tensor([ 0.1041, -0.0357, -0.0607, -5.3605,  0.3023])
# 함께 tensor([ 0.1631, -0.0222,  0.1655, -6.1085,  0.1454])
# 산만하다 tensor([ 0.0782, -0.0703,  0.2220, -5.6843,  0.2439])
# 에서는 tensor([ 0.0833, -0.0143,  0.1652, -6.1098,  0.1879])
# 실용 tensor([-0.0919, -0.4502,  0.1640, -4.1547,  0.1547])
# 랑 tensor([ 0.2024, -0.0832,  0.1683, -4.5429,  0.2899])
# 그게 tensor([ 0.0181, -0.1480,  0.2712, -4.8671,  0.1625])
# 시키다 tensor([ 0.1298, -0.1393,  0.3129, -4.9391,  0.1863])
# 에도 tensor([ 0.1318, -0.0333,  0.1540, -5.2244,  0.2699])
# 나르다 tensor([ 0.0841, -0.1081,  0.2802, -4.6601,  0.2231])
# 싫다 tensor([ 0.0429, -0.1745,  0.2388, -5.0464,  0.2007])
# 라 tensor([ 0.0286, -0.1054,  0.2744, -5.3334,  0.3045])
# 두다 tensor([ 0.0692, -0.1682,  0.2773, -4.8908,  0.2142])
# 이유 tensor([ 0.0703, -0.1672,  0.2476, -4.8732,  0.1420])
# 지 tensor([ 0.0103,  0.1767,  0.2413, -5.5521,  0.2346])
# 나누다 tensor([ 0.1066, -0.1527,  0.2707, -4.9067,  0.2170])
# 이상 tensor([-0.1421,  0.0555,  0.1645, -5.3032,  0.2439])
# 몇 tensor([ 0.0844, -0.1483,  0.1038, -4.8083,  0.1865])
# 결정 tensor([ 0.0588, -0.0443,  0.0835, -5.6410,  0.1882])
# 돈 tensor([ 0.1683,  0.0612,  0.2848, -5.0551,  0.1093])
# 쉬다 tensor([ 0.0647, -0.1342,  0.2341, -5.1119,  0.2325])
# 열심히 tensor([ 0.0319, -0.1447,  0.2793, -5.0403,  0.2557])
# 화가 tensor([ 0.0824, -0.1642,  0.3281, -4.9779,  0.2305])
# 머리 tensor([-5.0792e-02, -2.8916e-03,  2.1143e-01, -5.6144e+00,  1.5850e-01])
# 년 tensor([ 0.0437,  0.0555,  0.3025, -5.6154,  0.1459])
# 선택 tensor([ 0.0667, -0.1564,  0.2869, -4.9387,  0.1846])
# 실리 tensor([-0.1330, -0.4690,  0.1644, -4.0826,  0.2153])
# 어리다 tensor([ 0.0181, -0.1928,  0.2245, -4.9193,  0.2428])
# 처럼 tensor([ 0.2914,  0.0125,  0.2879, -4.5022,  0.2335])
# 찾다 tensor([ 0.0433, -0.1541,  0.3065, -5.0192,  0.1860])
# 기도 tensor([ 0.1661,  0.0090,  0.2966, -5.2976,  0.2512])
# 동료 tensor([ 0.0873, -0.1374,  0.2447, -5.0527,  0.1697])
# 돼다 tensor([ 0.0236, -0.1632,  0.3437, -4.6614,  0.1774])
# 이라 tensor([ 0.0663, -0.0337,  0.2486, -4.5154,  0.2289])
# 설득 tensor([ 0.0598, -0.1089,  0.2707, -4.9623,  0.2050])
# 스스로 tensor([ 0.0699, -0.1034,  0.2953, -5.2037,  0.2588])
# 또 tensor([ 0.0514, -0.0288,  0.1127, -4.8834,  0.3013])
# 사실 tensor([-2.5867e-03,  2.8170e-03,  7.1379e-02, -5.5566e+00,  9.8481e-02])
# 화 tensor([-0.1024, -0.1095,  0.1796, -5.7116,  0.1114])
# 평소 tensor([ 0.0203, -0.1294,  0.2796, -5.2989,  0.2170])
# 시험 tensor([ 0.0584, -0.0752, -0.0325, -6.1831, -0.0861])
# 속 tensor([ 0.1422, -0.0672,  0.2644, -5.2464,  0.1719])
# 생활 tensor([-0.0129, -0.0295,  0.0947, -6.1316,  0.1560])
# 보이다 tensor([ 0.0732, -0.2033,  0.2515, -4.8723,  0.2056])
# 대인관계 tensor([ 0.0090, -0.1873,  0.2058, -5.3176,  0.2042])
# 끄다 tensor([ 0.0742, -0.0631,  0.3009, -5.1736,  0.2297])
# 결과 tensor([ 0.0894, -0.1011,  0.1666, -5.6154,  0.1923])
# 준비 tensor([ 0.1347, -0.0311, -0.0219, -5.9401,  0.1914])
# 두 tensor([ 0.0951, -0.1919,  0.2366, -4.7315,  0.4905])
# 날 tensor([ 0.1374, -0.1011,  0.0922, -5.1113,  0.2939])
# 모든 tensor([ 0.0535, -0.2008,  0.2533, -4.9732,  0.2064])
# 그런 tensor([ 0.0594, -0.0581,  0.0091, -5.6298,  0.2317])
# 통해 tensor([ 0.0825, -0.1804,  0.3543, -4.6436,  0.1616])
# 인정받다 tensor([ 0.0119, -0.1733,  0.2317, -4.9805,  0.0739])
# 지만 tensor([ 0.1720,  0.0218,  0.2820, -5.6490,  0.2548])
# 예술 tensor([-0.0318, -0.5211,  0.0997, -4.6015,  0.0375])
# 다음 tensor([ 0.0552, -0.2378,  0.2646, -4.9306,  0.2102])
# 고통 tensor([ 0.0873, -0.0575,  0.2581, -5.0269,  0.2829])
# 살다 tensor([ 0.0800, -0.1504,  0.2701, -4.8284,  0.2148])
# 진행 tensor([ 0.0640, -0.1626,  0.2685, -4.9289,  0.1943])
# 대부분 tensor([ 0.0203, -0.1236,  0.2492, -5.2931,  0.1969])
# 언니 tensor([ 0.0437, -0.1777,  0.2800, -4.3376,  0.1981])
# 설명 tensor([ 0.0668, -0.1423,  0.2939, -5.2565,  0.2114])
# 방법 tensor([ 0.0761, -0.1838,  0.2753, -4.5659,  0.1695])
# 력 tensor([ 0.1672, -0.0721,  0.1472, -5.9968,  0.2035])
# 예전 tensor([ 0.0336, -0.1238,  0.2140, -5.0057,  0.2237])
# 쪽 tensor([ 0.1667,  0.0129,  0.1915, -5.9454,  0.2049])
# 우선 tensor([-0.0323, -0.1652,  0.2814, -4.8690,  0.2035])
# 굽히다 tensor([ 0.1295, -0.1122,  0.2774, -5.1891,  0.2033])
# 필요하다 tensor([ 0.0580, -0.1883,  0.3253, -5.0209,  0.2182])
# 네 tensor([ 0.0297, -0.0562,  0.1555, -4.4129,  0.3217])
# 글 tensor([-0.0397,  0.0590,  0.1210, -4.5759,  0.2599])
# 그러나 tensor([ 0.0433, -0.1439,  0.2972, -4.6171,  0.2607])
# 정리 tensor([ 0.1239, -0.1568,  0.2857, -5.0467,  0.2357])
# 과정 tensor([ 0.1225, -0.0730,  0.1127, -5.7459,  0.1631])
# 학교 tensor([ 0.1206, -0.2131,  0.0341, -6.2067,  0.0439])
# 거리 tensor([ 0.1279, -0.0201,  0.2424, -5.8793,  0.1234])
# 꿈 tensor([-0.0353, -0.1104,  0.0418, -4.7419, -0.0092])
# 사귀다 tensor([-0.1273, -0.0409,  0.2687, -4.6559,  0.1204])
# 엔 tensor([-0.1173, -0.0391,  0.0551, -4.6053,  0.2695])
# 나이 tensor([ 0.1018, -0.1314,  0.2827, -4.7999,  0.2156])
# 영화 tensor([ 0.2001, -0.4600,  0.2405, -5.5796,  0.1299])
# 대로 tensor([ 0.2876, -0.0102,  0.2045, -5.6842,  0.2688])
# 갑자기 tensor([ 0.0686, -0.0998,  0.3003, -5.0911,  0.2131])
# 가지다 tensor([ 0.0363, -0.1684,  0.3169, -4.9412,  0.2297])
# 진짜 tensor([ 0.0924, -0.0424,  0.1089, -5.5927,  0.1893])
# 세우다 tensor([ 0.0280, -0.0903,  0.2793, -4.8972,  0.1551])
# 아무 tensor([ 0.0106, -0.1961,  0.2732, -4.6095,  0.1891])
# 관련 tensor([ 0.0596, -0.0598,  0.2009, -5.6678,  0.1955])
# 요즘 tensor([ 0.0793, -0.1669,  0.2698, -5.0915,  0.1582])
# 개인 tensor([-0.0481, -0.2519,  0.2038, -4.9422,  0.2460])
# 나서다 tensor([ 0.1129, -0.1040,  0.3162, -5.0204,  0.2129])
# 씩 tensor([ 0.1883,  0.0991,  0.2056, -5.4103,  0.2781])
# 자리 tensor([ 0.2856, -0.0297,  0.3949, -4.6482, -0.0832])
# 남자친구 tensor([ 0.0850, -0.1568,  0.2337, -4.7165,  0.2189])
# 위 tensor([ 0.2619, -0.0247,  0.2331, -5.4826,  0.2165])
# 분명하다 tensor([ 0.0172, -0.2033,  0.2050, -5.1993,  0.2111])
# 꼭 tensor([ 0.1961, -0.0268,  0.2017, -5.6372,  0.2389])
# 마무리 tensor([-0.0419, -0.1544,  0.1394, -5.2483,  0.1210])
# 니까 tensor([ 0.0388, -0.1755,  0.0329, -3.5363,  0.2894])
# 해도 tensor([ 0.0672, -0.1027,  0.3170, -4.9425,  0.2596])
# 감 tensor([ 0.1626,  0.0298,  0.1856, -5.8298,  0.1060])
# 자기 tensor([ 0.0318, -0.1450,  0.2487, -4.7381,  0.2010])
# 입장 tensor([ 0.1178, -0.2005,  0.2617, -4.7206,  0.2385])
# 너 tensor([ 0.1510, -0.0892,  0.1188, -4.8863,  0.3096])
# 특별하다 tensor([ 0.0383, -0.1162,  0.2338, -5.5026,  0.2020])
# 바로 tensor([ 0.0654, -0.1298,  0.2534, -5.0986,  0.2277])
# 사소하다 tensor([ 0.0409, -0.2151,  0.2910, -4.8227,  0.1854])
# 인하다 tensor([ 0.0662, -0.0748,  0.1689, -5.1672,  0.2574])
# 운동 tensor([ 0.0836, -0.0383, -0.0257, -5.6631,  0.1794])
# 비슷하다 tensor([ 0.1130, -0.1062,  0.2835, -5.2960,  0.2358])
# 철학 tensor([-0.0887, -0.3856,  0.1820, -4.3407,  0.3274])
# 들어서다 tensor([-1.7670e-03, -1.2834e-01,  2.6758e-01, -4.6373e+00,  2.2716e-01])
# 창조 tensor([-0.1388, -0.4247,  0.1419, -4.0607,  0.1790])
# 작업 tensor([ 0.0409, -0.0571,  0.1535, -5.5468,  0.0135])
# 모습 tensor([ 0.0523, -0.1736,  0.3407, -4.5298,  0.2050])
# 느껴지다 tensor([ 0.0918, -0.1428,  0.3098, -4.9236,  0.1335])
# 갖다 tensor([ 0.0294, -0.1545,  0.3059, -5.0194,  0.1468])
# 종종 tensor([ 0.0849, -0.1951,  0.2718, -4.7508,  0.1513])
# 엄마 tensor([ 0.0326, -0.1656,  0.2037, -4.8994,  0.2430])
# 양보 tensor([ 0.0434, -0.1332,  0.3001, -4.9905,  0.2210])
# 이르다 tensor([ 0.0453, -0.1865,  0.3241, -4.4643,  0.2208])
# 구 tensor([ 0.2299, -0.1447,  0.0237, -5.7236,  0.2332])
# 피해 tensor([ 0.1033, -0.0558,  0.0598, -5.9765,  0.1737])
# 끝 tensor([ 0.0451,  0.0274,  0.2139, -4.6131,  0.2538])
# 걸리다 tensor([ 0.0429, -0.1017,  0.2748, -5.1160,  0.2052])
# 오히려 tensor([ 0.0633, -0.1586,  0.2677, -4.5192,  0.1864])
# 줄 tensor([ 0.1119, -0.0077,  0.2740, -5.4757,  0.0679])
# 굳이 tensor([ 0.0476, -0.1561,  0.2814, -4.8180,  0.1779])
# 서다 tensor([ 0.1171, -0.1272,  0.3530, -4.8357,  0.2214])
# 순간 tensor([ 0.0905, -0.1701,  0.3161, -4.6956,  0.1914])
# 밥 tensor([ 0.1618,  0.0655,  0.3531, -5.8789,  0.1603])
# 지다 tensor([ 0.0913, -0.1356,  0.2938, -5.0725,  0.1877])
# 매우 tensor([ 0.0723, -0.0853,  0.2823, -5.1063,  0.2561])
# 앞서다 tensor([-0.0088, -0.1142,  0.3028, -5.3582,  0.1517])
# 최근 tensor([ 0.0934,  0.0282,  0.0832, -6.2009,  0.2415])
# 잘못 tensor([ 0.0193, -0.1128,  0.2946, -5.1466,  0.2267])
# 만약 tensor([ 0.0315, -0.1423,  0.3023, -4.8753,  0.1809])
# 솔직하다 tensor([ 0.0295, -0.1826,  0.2847, -4.5833,  0.1565])
# 기존 tensor([-0.0072, -0.0552,  0.2772, -5.3174,  0.2177])
# 즐기다 tensor([ 0.0935, -0.1853,  0.2849, -5.0392,  0.1301])
# 들어주다 tensor([ 0.0743, -0.1538,  0.2716, -4.7728,  0.1785])
# 하루 tensor([ 0.1367, -0.1433,  0.2990, -4.6648,  0.1497])
# 술 tensor([-0.1051, -0.0501,  0.1264, -5.7528,  0.0595])
# 딱하다 tensor([ 0.0614, -0.1440,  0.2584, -5.1433,  0.2175])
# 구분 tensor([ 0.0755, -0.0916,  0.3192, -5.2044,  0.2013])
# 엄청 tensor([ 0.0844, -0.1183,  0.3063, -4.7721,  0.2450])
# 편하다 tensor([ 0.0849, -0.1208,  0.2973, -5.1096,  0.2084])
# 그래도 tensor([ 0.0884, -0.1830,  0.3137, -4.4634,  0.2090])
# 이익 tensor([ 0.0926,  0.0514,  0.1307, -5.8435,  0.0898])
# 매사 tensor([ 0.0748, -0.0549,  0.2121, -5.6382,  0.2258])
# 펴다 tensor([ 0.1132, -0.1564,  0.2930, -4.7939,  0.2084])
# 밖에 tensor([ 0.1626,  0.0370,  0.1073, -5.2922,  0.1243])
# 본인 tensor([ 0.0292, -0.0630,  0.2724, -5.2398,  0.1845])
# 근데 tensor([ 0.1005, -0.2010,  0.3061, -4.2395,  0.1642])
# 그걸 tensor([ 0.0885, -0.1901,  0.2873, -4.1253,  0.1617])
# 막 tensor([ 0.1714, -0.0783,  0.2163, -4.9294,  0.4491])
# 사회 tensor([ 0.0242, -0.2063,  0.0560, -5.8224,  0.1216])
# 예요 tensor([-0.0845, -0.2262,  0.2886, -4.4347,  0.2251])
# 그거 tensor([ 0.0564, -0.1984,  0.2935, -4.4361,  0.1776])
# 발생 tensor([ 0.0996, -0.0862,  0.2635, -5.1508,  0.2102])
# 추상 tensor([-0.1011, -0.4157,  0.1832, -4.2762,  0.2951])
# 고등학교 tensor([ 2.1512e-01, -4.5513e-03,  7.9197e-02, -6.1809e+00,  3.3963e-01])
# 무슨 tensor([ 0.0783, -0.1529,  0.2795, -5.0368,  0.2224])
# 말다 tensor([ 0.0696, -0.1158,  0.3433, -4.7960,  0.2352])
# 내용 tensor([ 0.1218, -0.1724,  0.2900, -4.7977,  0.2044])
# 가깝다 tensor([ 0.0501, -0.1954,  0.2348, -4.8615,  0.2253])
# 뿐 tensor([ 0.0970,  0.1528,  0.0506, -5.1209,  0.1965])
# 아이 tensor([ 0.0133, -0.1369, -0.0508, -4.8956,  0.0203])
# 다만 tensor([ 0.0843, -0.1391,  0.2537, -5.0419,  0.1795])
# 현실 tensor([ 0.0414, -0.1965,  0.2452, -4.5054,  0.2090])
# 강하다 tensor([ 0.0599, -0.0854,  0.3396, -4.9935,  0.2163])
# 상사 tensor([ 0.0653, -0.1424,  0.3016, -4.8861,  0.2062])
# 뒤 tensor([ 0.1391,  0.0229,  0.1742, -4.5469,  0.1860])
# 옳다 tensor([ 0.0787, -0.0620,  0.2961, -5.0916,  0.2085])
# 굉장하다 tensor([ 0.0370, -0.1616,  0.3177, -4.6206,  0.1895])
# 충분하다 tensor([ 0.1106, -0.1197,  0.2623, -5.0286,  0.1788])
# 여유 tensor([ 0.0624, -0.2524,  0.1833, -5.1161,  0.0400])
# 다툼 tensor([ 0.0054, -0.1624,  0.2480, -5.2164,  0.1147])
# 되게 tensor([ 0.1067, -0.1820,  0.2688, -4.4256,  0.2437])
# 또한 tensor([ 0.0111, -0.1089,  0.3094, -4.7712,  0.1961])
# 수도 tensor([ 0.0794, -0.2828,  0.2999, -4.4456,  0.0741])
# 에요 tensor([ 0.0716, -0.1328,  0.2728, -4.8857,  0.1636])
# 여 tensor([ 0.2138, -0.1104,  0.3428, -5.2203,  0.2561])
# 오래 tensor([ 0.1103, -0.1621,  0.3094, -4.8348,  0.1921])
# 선 tensor([ 5.1026e-03,  2.0124e-01,  3.4416e-01, -5.4336e+00,  5.0871e-02])
# 나쁘다 tensor([ 0.0705, -0.1906,  0.2563, -4.6833,  0.1762])
# 볼 tensor([ 0.1016, -0.0475,  0.2680, -5.4078,  0.1946])
# 곳 tensor([ 0.1327,  0.0200,  0.1516, -5.8512,  0.1847])
# 불안하다 tensor([ 0.0577, -0.0877,  0.2829, -5.3340,  0.2007])
# 이기 tensor([ 0.0578, -0.0764,  0.2846, -5.1423,  0.2806])
# 물어보다 tensor([ 0.0971, -0.1097,  0.3166, -5.2316,  0.2240])
# 에서도 tensor([ 0.0359,  0.0469,  0.1665, -6.1058,  0.3081])
# 살 tensor([ 0.0949, -0.1825,  0.1386, -4.6851,  0.1105])
# 함 tensor([ 0.0280,  0.0757,  0.0490, -5.5455,  0.1183])
# 스트레스 tensor([ 0.0841, -0.1356,  0.2650, -4.8108,  0.2048])
# 갈다 tensor([ 0.0222, -0.1725,  0.3015, -4.9516,  0.2535])
# 이제 tensor([ 0.0771, -0.2369,  0.3369, -4.3153,  0.1356])
# 여러 tensor([ 0.0109, -0.1952,  0.2745, -5.0410,  0.1843])
# 버리다 tensor([ 0.0662, -0.1330,  0.3221, -4.8350,  0.2170])
# 데 tensor([ 0.0940, -0.0966,  0.2319, -5.0887,  0.2536])
# 상태 tensor([ 0.0733, -0.0820,  0.0773, -5.7051,  0.0459])
# 넘어가다 tensor([ 0.0791, -0.1110,  0.2592, -4.8163,  0.1999])
# 나중 tensor([ 0.1533, -0.1328,  0.3089, -4.9140,  0.2091])
# 중학교 tensor([ 0.0306, -0.1160,  0.1975, -5.0796,  0.2677])
# 듭니 tensor([ 0.0183, -0.1089,  0.2091, -5.0590,  0.0660])
# 지키다 tensor([ 0.0450, -0.1431,  0.2898, -4.9616,  0.2030])
# 판단 tensor([-0.0162, -0.1106,  0.2152, -5.1663,  0.2207])
# 간 tensor([ 0.1479,  0.1193,  0.1941, -5.2999,  0.3716])
# 써다 tensor([ 0.0980, -0.1532,  0.2714, -4.7002,  0.2529])
# 보기 tensor([ 0.1799,  0.0094,  0.2560, -5.4185,  0.2873])
# 바꾸다 tensor([ 0.0772, -0.1585,  0.3118, -4.8708,  0.2376])
# 대 tensor([ 0.3145, -0.0209,  0.1796, -5.7548,  0.2171])
# 현재 tensor([ 0.0801, -0.0919,  0.0465, -4.6914,  0.0641])
# 주 tensor([ 0.1473, -0.1479,  0.2045, -5.4232,  0.0780])
# 그런데 tensor([ 0.0691, -0.1687,  0.3343, -4.6918,  0.2046])
# 음식 tensor([ 0.1268, -0.1666,  0.2780, -5.1153,  0.1378])
# 자체 tensor([ 0.0087, -0.2220,  0.2156, -4.6673,  0.1651])
# 전혀 tensor([ 0.0977, -0.0700,  0.2320, -5.2622,  0.2364])
# 타인 tensor([ 0.0418, -0.1413,  0.2855, -4.8826,  0.2526])
# 방향 tensor([ 0.1368,  0.0637,  0.2125, -5.7469,  0.1366])
# 이라는 tensor([ 0.0614,  0.1035,  0.1985, -5.5350,  0.1944])
# 달라 tensor([ 0.2047, -0.0313,  0.1637, -5.2533,  0.1364])
# 대학 tensor([ 1.0251e-01, -4.4411e-03,  1.1268e-02, -6.0595e+00,  1.1552e-01])
# 배우다 tensor([ 0.0336, -0.1479,  0.2865, -4.8010,  0.1791])
# 이랑 tensor([ 0.0673, -0.1747,  0.3154, -4.3464,  0.1332])
# 부모님 tensor([ 0.0438, -0.1038,  0.1740, -5.0791,  0.1686])
# 누군가 tensor([ 0.0588, -0.1039,  0.2799, -5.2440,  0.1853])
# 의미 tensor([ 0.0959, -0.1616,  0.3279, -4.5977,  0.1994])
# 눈 tensor([ 0.1073,  0.0142,  0.1798, -5.7945,  0.1974])
# 보 tensor([ 0.3755, -0.1230,  0.0885, -4.6927, -0.0575])
# 수학 tensor([ 0.1196, -0.1837,  0.2555, -5.0484,  0.1706])
# 남다 tensor([ 0.0800, -0.2172,  0.2920, -4.4597,  0.1881])
# 사이 tensor([ 0.0521, -0.1254,  0.3091, -4.9493,  0.1924])
# 힘드다 tensor([ 0.0263, -0.2169,  0.2946, -4.6188,  0.2373])
# 에게는 tensor([ 1.3612e-01, -4.1323e-03,  1.3906e-01, -5.4400e+00,  2.0431e-01])
# 님 tensor([ 4.2925e-03,  6.3270e-02,  1.3240e-01, -4.9334e+00,  9.9053e-02])
# 미래 tensor([ 0.1486, -0.2138,  0.0846, -5.4822,  0.1338])
# 믿음 tensor([ 0.0461, -0.1540,  0.2652, -4.7777,  0.2614])
# 불편하다 tensor([ 0.0704, -0.1529,  0.2820, -4.5917,  0.2136])
# 작다 tensor([ 0.0379, -0.1639,  0.2377, -4.8074,  0.1732])
# 지는 tensor([ 0.1301,  0.0232,  0.2355, -6.0518,  0.2303])
# 생기 tensor([ 0.0653, -0.1703,  0.2909, -4.7749,  0.0558])
# 팀 tensor([ 0.0614, -0.1132,  0.1574, -4.9437,  0.4226])
# 반응 tensor([ 0.0726, -0.1479,  0.2756, -4.8145,  0.1526])
# 누구 tensor([ 0.0777, -0.2204,  0.2185, -4.6256,  0.1515])
# 주장 tensor([ 0.0393, -0.1562,  0.3292, -4.7757,  0.1671])
# 다른사람 tensor([ 0.0613, -0.0906,  0.1891, -5.5773,  0.2001])
# 위로 tensor([ 0.1701,  0.0151,  0.1825, -6.2498,  0.1911])
# 맡다 tensor([ 0.1158, -0.1547,  0.2736, -5.1075,  0.2426])
# 아프다 tensor([ 0.0750, -0.0980,  0.2693, -5.3100,  0.1481])
# 직접 tensor([ 0.0665, -0.2213,  0.2503, -4.6583,  0.2091])
# 맛있다 tensor([ 0.0780, -0.1924,  0.2730, -4.9134,  0.2009])
# 겪다 tensor([ 0.0706, -0.1342,  0.2238, -4.8972,  0.1670])
# 난 tensor([ 0.0173, -0.0072, -0.0098, -5.0987,  0.3174])
# 일어나다 tensor([ 0.0598, -0.1855,  0.2649, -4.7965,  0.2022])
# 여행 tensor([ 0.1027, -0.0533,  0.0108, -6.0034,  0.1305])
# 땐 tensor([ 0.1676, -0.0437,  0.1242, -5.5902,  0.2896])
# 원래 tensor([ 0.0050, -0.1471,  0.2422, -4.9489,  0.1618])
# 라서 tensor([ 0.0824, -0.1122,  0.3308, -5.0467,  0.1907])
# 모임 tensor([ 0.0754, -0.1972,  0.1876, -5.0546,  0.1946])
# 프로젝트 tensor([ 0.0884, -0.2020,  0.2805, -4.7953,  0.1766])
# 깊다 tensor([ 0.0837, -0.0717,  0.2461, -5.4635,  0.2334])
# 서운하다 tensor([ 0.0805, -0.1390,  0.2761, -4.9595,  0.2446])
# 피 tensor([-0.0661, -0.2611, -0.1330, -5.3255,  0.4414])
# 매일 tensor([ 0.0543, -0.0760,  0.2469, -5.2367,  0.2158])
# 싫어하다 tensor([ 0.0541, -0.1316,  0.2759, -5.0957,  0.1664])
# 만큼 tensor([ 0.1236,  0.0702,  0.1715, -5.6580,  0.1517])
# 칭찬 tensor([ 0.0948, -0.1170,  0.1927, -4.9459,  0.1625])
# 늘다 tensor([ 0.0995, -0.1321,  0.1991, -5.0116,  0.2365])
# 조언 tensor([ 0.0637, -0.1772,  0.1296, -4.8482,  0.1673])
# 뜻대로 tensor([ 0.0569, -0.1286,  0.3125, -5.1007,  0.2573])
# 거기 tensor([ 0.0387, -0.2010,  0.3491, -4.5573,  0.1127])
# 과의 tensor([-0.0079, -0.0722,  0.2201, -5.2852,  0.2108])
# 후회 tensor([ 0.0759, -0.0835,  0.3468, -5.0426,  0.2071])
# 받아들이다 tensor([-0.0136, -0.1248,  0.2678, -5.6084,  0.2650])
# 피하 tensor([ 0.0842, -0.2110,  0.2887, -4.6582,  0.1043])
# 들어가다 tensor([ 0.1143, -0.1252,  0.2533, -5.0065,  0.1845])
# 고통스럽다 tensor([ 0.0514, -0.0667,  0.2334, -5.1461,  0.1261])
# 직원 tensor([ 0.1354,  0.0760,  0.1448, -6.3455,  0.1593])
# 스럽게 tensor([ 0.2169,  0.0313,  0.2244, -6.6597,  0.1908])
# 전화 tensor([ 0.0912, -0.0835,  0.3186, -5.3240,  0.2359])
# 이후 tensor([ 0.0779, -0.1756,  0.2570, -4.8547,  0.2508])
# 물건 tensor([ 0.0113, -0.1318,  0.3082, -5.0118,  0.1957])
# 아 tensor([ 0.1298, -0.2940,  0.2266, -4.6705,  0.1974])
# 사람과 tensor([ 0.0709, -0.2025,  0.1635, -4.8528,  0.2120])
# 확인 tensor([ 0.0448, -0.1097,  0.1298, -5.4825,  0.0761])
# 옆 tensor([ 1.4074e-01,  1.0661e-01,  1.2511e-01, -5.2645e+00,  2.3762e-03])
# 질문 tensor([ 0.0551, -0.1991,  0.2686, -4.9208,  0.2305])
# 그리다 tensor([ 0.0513, -0.1457,  0.1871, -5.2069,  0.1907])
# 보지 tensor([ 0.0212, -0.1530,  0.2108, -5.1078,  0.1010])
# 이루다 tensor([-0.0172, -0.1672,  0.2290, -5.0879,  0.1841])
# 손 tensor([ 0.0380,  0.1073,  0.0733, -5.3710,  0.2196])
# 으로는 tensor([ 0.0481, -0.1255,  0.2836, -5.0041,  0.2343])
# 어쩔 tensor([-0.0704, -0.2262,  0.2840, -4.7274,  0.0702])
# 모두 tensor([ 0.0625, -0.1552,  0.2476, -5.1721,  0.2489])
# 세부 tensor([-0.1089, -0.2819,  0.0314, -4.9067,  0.1524])
# 취업 tensor([ 0.1243, -0.1508,  0.1794, -5.2855,  0.2342])
# 제일 tensor([ 0.0414, -0.0956,  0.2854, -4.5603,  0.1496])
# 얼마나 tensor([ 0.0611, -0.1298,  0.2990, -4.9887,  0.1726])
# 길 tensor([ 0.0265,  0.1734,  0.1758, -5.3382,  0.2552])
# 며 tensor([ 0.1699, -0.0524,  0.2201, -5.4637,  0.2349])
# 즐겁다 tensor([ 0.0617, -0.1410,  0.2803, -4.6581,  0.2393])
# 대학교 tensor([ 0.1358, -0.1015,  0.0141, -6.0820,  0.2649])
# 목적 tensor([ 0.0467, -0.1847,  0.2490, -5.0743,  0.0391])
# 든 tensor([ 0.1551,  0.0349,  0.1495, -5.4603,  0.2936])
# 풀다 tensor([ 0.0080, -0.1001,  0.2734, -4.9094,  0.2181])
# 성향 tensor([ 0.0818, -0.1598,  0.2637, -4.8409,  0.1886])
# 빠지다 tensor([ 0.0272, -0.1590,  0.2519, -5.1249,  0.2817])
# 사과 tensor([ 0.0842, -0.1614,  0.2541, -4.9595,  0.1977])
# 조용하다 tensor([ 0.0876, -0.1787,  0.2385, -5.0169,  0.1322])
# 취미 tensor([-4.1284e-03, -1.4312e-01,  2.1103e-01, -4.8844e+00,  1.8750e-01])
# 우울하다 tensor([ 0.1147, -0.2035,  0.2917, -4.7376,  0.2381])
# 시 tensor([ 0.0749, -0.0424,  0.0124, -5.9978,  0.1574])
# 게임 tensor([ 0.0584, -0.0765,  0.3714, -5.2332,  0.0940])
# 우리 tensor([ 0.1332, -0.1772,  0.1831, -4.4482,  0.2197])
# 명확하다 tensor([ 0.0450, -0.1609,  0.2833, -4.9913,  0.2164])
# 대하 tensor([ 0.1509, -0.2461,  0.2561, -4.8374,  0.0810])
# 공유 tensor([ 0.0272, -0.1663,  0.3064, -4.5516,  0.1420])
# 누가 tensor([ 0.0558, -0.1830,  0.3102, -4.5071,  0.2549])
# 다가가다 tensor([ 0.0206, -0.0893,  0.3107, -4.4743,  0.2007])
# 달성 tensor([ 0.0629, -0.1319,  0.2848, -4.8773,  0.1847])
# 보여주다 tensor([ 0.0235, -0.1314,  0.2509, -4.8895,  0.1596])
# 차다 tensor([ 0.1092, -0.1384,  0.2289, -4.8350,  0.1962])
# 무시 tensor([ 0.0608, -0.1083,  0.3088, -4.9216,  0.1872])
# 졸업 tensor([ 0.0771, -0.2009,  0.1774, -4.9100,  0.3552])
# 당연하다 tensor([ 0.1099, -0.1663,  0.3125, -4.7486,  0.1714])
# 걸다 tensor([ 0.1126,  0.0191,  0.2732, -4.9328,  0.2594])
# 도와주다 tensor([ 0.0220, -0.1409,  0.2928, -5.0861,  0.1958])
# 사용 tensor([ 0.0421, -0.1222,  0.3725, -5.1266,  0.2517])
# 늘 tensor([ 0.0328,  0.0891,  0.1808, -6.4971,  0.1795])
# 나름 tensor([ 0.1066, -0.1339,  0.2415, -5.2414,  0.2144])
# 그대로 tensor([ 0.0477, -0.1571,  0.2895, -4.8340,  0.2089])
# 무언가 tensor([ 0.1152, -0.1369,  0.1509, -5.0274,  0.1932])
# 표 tensor([ 0.0764,  0.0690,  0.1109, -5.5105,  0.1491])
# 또는 tensor([ 1.9822e-03, -1.6910e-01,  2.2539e-01, -5.0490e+00,  2.5783e-01])
# 사고 tensor([-0.0600, -0.1076,  0.0234, -6.2740,  0.1935])
# 어려움 tensor([ 0.1392, -0.1325,  0.2660, -5.0398,  0.1763])
# 결혼 tensor([ 0.0747, -0.0700,  0.0988, -5.6554,  0.0476])
# 퇴사 tensor([ 5.1069e-03, -1.0713e-01,  3.4269e-01, -5.3156e+00,  2.0262e-01])
# 만의 tensor([ 0.0128, -0.2280,  0.2392, -5.0541,  0.2168])
# 장문 tensor([ 0.0635, -0.2059,  0.2840, -5.3608,  0.3507])
# 이러하다 tensor([ 0.0317, -0.1556,  0.2889, -4.6435,  0.2833])
# 마다 tensor([ 0.2055,  0.0547,  0.2048, -4.2316,  0.2394])
# 최선 tensor([ 0.0639, -0.1750,  0.2753, -4.6845,  0.1494])
# 지나다 tensor([ 0.0568, -0.0997,  0.3057, -5.2988,  0.2425])
# 놓다 tensor([-0.0074, -0.1950,  0.2592, -5.1848,  0.2783])
# 혼동 tensor([ 0.1273, -0.1112,  0.3861, -5.1843,  0.2430])
# 과는 tensor([ 0.0780, -0.0882,  0.2630, -4.9673,  0.2101])
# 상처 tensor([ 0.0727, -0.1571,  0.2801, -4.6560,  0.2424])
# 대다 tensor([-0.0353, -0.1645,  0.3191, -4.6678,  0.1744])
# 이런 tensor([ 0.0293, -0.2856,  0.2255, -4.5124,  0.1680])
# 라도 tensor([ 0.1885, -0.0445,  0.2366, -5.7067,  0.1292])
# 야하다 tensor([ 0.0787, -0.1955,  0.2604, -4.7922,  0.1147])
# 여서 tensor([ 0.0812, -0.1854,  0.3036, -5.0720,  0.1901])
# 기 tensor([ 0.1373,  0.0321,  0.2702, -5.4113,  0.4652])
# 산책 tensor([ 0.0850, -0.0826,  0.2463, -5.3097,  0.1870])
# 가능하다 tensor([ 0.0243, -0.1393,  0.2800, -4.9702,  0.2029])
# 기적 tensor([-0.0092, -0.1171,  0.2507, -5.0306,  0.1792])
# 챙기다 tensor([ 0.0921, -0.1633,  0.3218, -4.6980,  0.1695])
# 드라마 tensor([ 0.1191, -0.3072,  0.2798, -5.7353,  0.1155])
# 한적 tensor([ 0.1001, -0.1750,  0.2355, -5.4392,  0.0953])
# 해당 tensor([ 0.0873, -0.1730,  0.3244, -5.1225,  0.2561])
# 진로 tensor([ 0.0909, -0.1550,  0.1410, -5.4223,  0.1643])
# 오해 tensor([ 0.0994, -0.1349,  0.2776, -4.7811,  0.2060])
# 이지 tensor([-0.0174, -0.0900,  0.2327, -4.9295,  0.2149])
# 따다 tensor([ 0.1446, -0.1384,  0.2177, -4.9039,  0.1461])
# 늦다 tensor([ 0.1308, -0.1899,  0.2700, -4.9481,  0.2399])
# 필요 tensor([ 0.0226, -0.2017,  0.3319, -4.6452,  0.0719])
# 약속 tensor([ 0.0863, -0.1723,  0.2669, -5.0151,  0.2047])
# 건지다 tensor([ 0.1142, -0.1173,  0.3198, -4.8854,  0.2330])
# 재밌다 tensor([ 0.0537, -0.2475,  0.2745, -4.3763,  0.1761])
# 치다 tensor([ 0.1164, -0.1332,  0.2344, -4.8445,  0.2143])
# 진가 tensor([-0.0643, -0.1038,  0.2528, -5.3845,  0.0921])
# 소리 tensor([ 0.1766, -0.0725,  0.1904, -5.6963,  0.1667])
# 오늘 tensor([ 0.1009,  0.0137,  0.0723, -4.9003,  0.3051])
# 이라도 tensor([ 0.1306, -0.0054,  0.2389, -5.4135,  0.2267])
# 성적 tensor([ 0.0235, -0.1738,  0.3309, -5.1714,  0.1814])
# 참다 tensor([ 0.0355, -0.1661,  0.3505, -5.0466,  0.1729])
# 얻다 tensor([ 0.0273, -0.1950,  0.2916, -4.7926,  0.2406])
# 여러가지 tensor([ 0.0887, -0.0993,  0.2143, -5.0233,  0.2131])
# 특히 tensor([ 0.0769, -0.0549,  0.1956, -6.6083,  0.2038])
# 빨리 tensor([ 0.0568, -0.1091,  0.2582, -4.7993,  0.1798])
# 빠르다 tensor([ 0.0462, -0.1779,  0.3073, -5.3489,  0.1852])
# 건강 tensor([ 1.2646e-03, -7.2047e-02,  1.9157e-01, -6.0463e+00,  8.4459e-02])
# 웬만하다 tensor([-0.0588, -0.1113,  0.2554, -4.6871,  0.2031])
# 다양하다 tensor([ 0.0350, -0.1122,  0.3605, -4.8215,  0.2600])
# 만난 tensor([ 0.0825, -0.1411,  0.1917, -5.2051,  0.2306])
# 싸우다 tensor([ 0.0965, -0.1952,  0.2195, -5.2747,  0.1363])
# 잠 tensor([ 0.0185, -0.0089,  0.1250, -5.1741,  0.1194])
# 한다는 tensor([ 1.4919e-01,  4.5059e-03,  1.6772e-01, -5.9549e+00,  1.1954e-01])
# 대처 tensor([ 0.0308, -0.2328,  0.3761, -4.5926,  0.1868])
# 삶 tensor([ 0.0340, -0.0071,  0.2001, -5.0274, -0.0141])
# 그건 tensor([ 0.0544, -0.1732,  0.2742, -4.4388,  0.2224])
# 풀리다 tensor([ 0.1094, -0.1421,  0.2013, -4.6516,  0.1771])
# 쓸다 tensor([ 0.0597, -0.1756,  0.2967, -4.8238,  0.1874])
# 달 tensor([ 0.0279, -0.0191,  0.3137, -5.5527,  0.3328])
# 자연 tensor([ 0.0930, -0.1863,  0.2384, -5.0788,  0.2919])
# 주제 tensor([ 0.0328, -0.1230,  0.3387, -4.6608,  0.1927])
# 선물 tensor([ 0.1069, -0.0304,  0.2195, -6.3996,  0.1646])
# 그러면 tensor([ 0.0750, -0.1811,  0.3334, -4.4865,  0.2096])
# 물론 tensor([ 0.0762, -0.1201,  0.3140, -5.0035,  0.1511])
# 인거 tensor([ 0.0534,  0.0084,  0.2390, -5.0819,  0.2051])
# 지속 tensor([-0.0220, -0.3207,  0.2428, -4.6989,  0.2454])
# 관 tensor([ 0.0902,  0.0350, -0.0455, -5.9811,  0.1630])
# 말로 tensor([ 0.1048, -0.2383,  0.3073, -5.0589,  0.2512])
# 듯 tensor([ 0.1224,  0.0565,  0.2168, -5.9519,  0.2097])
# 당하다 tensor([ 0.0892, -0.0655,  0.3536, -5.0416,  0.1528])
# 인가 tensor([ 0.0223, -0.1604,  0.2242, -4.6220,  0.1596])
# 자격증 tensor([ 0.1082, -0.1151,  0.2075, -5.0026,  0.1340])
# 학년 tensor([ 0.1160,  0.0199, -0.1291, -5.8413,  0.4067])
# 요청 tensor([ 0.1140, -0.1917,  0.2340, -4.8134,  0.2466])
# 반 tensor([ 0.2882, -0.0555,  0.1550, -5.5686,  0.2748])
# 다수 tensor([ 0.0401, -0.0397,  0.3215, -5.5881,  0.2788])
# 티 tensor([ 3.8037e-03, -6.6417e-03,  2.1041e-01, -5.8487e+00,  3.7002e-01])
# 심하다 tensor([ 0.1039, -0.1816,  0.2973, -4.6841,  0.2345])
# 중간 tensor([ 0.0641, -0.1691,  0.2184, -5.0215,  0.1826])
# 웃다 tensor([ 0.0801, -0.1158,  0.2555, -4.9144,  0.1445])
# 정 tensor([ 0.1937, -0.0193, -0.0264, -6.1338,  0.1977])
# 하자 tensor([ 0.0219, -0.0917, -0.1851, -3.8312,  0.1214])
# 찾아보다 tensor([ 0.0339, -0.1612,  0.3345, -5.2426,  0.2253])
# 에게도 tensor([ 0.0588, -0.1897,  0.3056, -4.9600,  0.2308])
# 달라지다 tensor([ 0.1073, -0.1184,  0.2694, -4.7381,  0.2296])
# 코로나 tensor([ 0.0064, -0.0520,  0.2541, -5.2796,  0.1754])
# 까지는 tensor([ 2.7178e-03, -1.3005e-01,  3.1895e-01, -4.9955e+00,  2.5050e-01])
# 틀리다 tensor([ 0.0693, -0.1393,  0.2541, -5.1592,  0.2052])
# 들이다 tensor([ 0.0653, -0.0792,  0.2102, -5.1623,  0.1757])
# 드리다 tensor([ 0.1038, -0.1257,  0.2791, -5.0754,  0.1906])
# 끝내다 tensor([-0.0252, -0.1873,  0.1842, -5.1304,  0.1743])
# 자료 tensor([ 0.1584, -0.2399,  0.1522, -5.7245,  0.1341])
# 유리하다 tensor([ 0.0667, -0.2197,  0.1460, -5.2610,  0.2256])
# 괜찮다 tensor([ 0.1555, -0.1430,  0.2154, -4.8712,  0.1762])
# 성 tensor([-0.0602, -0.0255,  0.4338, -5.8470,  0.0877])
# 내리다 tensor([ 0.0637, -0.0964,  0.3015, -5.2568,  0.1970])
# 선생님 tensor([ 0.0877, -0.1927,  0.2590, -5.1264,  0.2892])
# 해내다 tensor([ 0.0703, -0.2343,  0.3120, -4.7995,  0.1727])
# 그날 tensor([ 0.0857, -0.1891,  0.3077, -5.1187,  0.2096])
# 둘 tensor([ 0.0556, -0.0152,  0.2715, -5.4318,  0.3029])
# 음악 tensor([ 0.1367, -0.0937,  0.3256, -5.6742, -0.0223])
# 일주일 tensor([ 0.0296, -0.2105,  0.2467, -4.8319,  0.1654])
# 절대 tensor([ 0.0804, -0.1854,  0.2801, -4.5608,  0.2984])
# 의도 tensor([ 0.0084, -0.1941,  0.2104, -5.1129,  0.1991])
# 반대 tensor([-0.0366, -0.0916,  0.2795, -3.7657,  0.0711])
# 포기 tensor([ 0.0723, -0.2274,  0.2256, -4.6938,  0.1271])
# 아주 tensor([ 0.0695, -0.0758,  0.2897, -5.3133,  0.1364])
# 이면 tensor([ 0.1385, -0.0574,  0.2853, -4.8251,  0.2186])
# 란 tensor([ 0.1048,  0.0505,  0.1032, -5.2977,  0.1991])
# 상담 tensor([ 0.0332, -0.0249,  0.2034, -6.1310,  0.2559])
# 똑같다 tensor([ 0.0827, -0.1780,  0.2748, -4.9697,  0.2783])
# 존중 tensor([ 0.0838, -0.1078,  0.3679, -5.2036,  0.1996])
# 뭘 tensor([ 0.1005,  0.0421,  0.1134, -6.2610,  0.2244])
# 넘다 tensor([ 0.0935, -0.1657,  0.2613, -5.0986,  0.2501])
# 생각나다 tensor([ 0.1006, -0.1771,  0.2770, -4.7298,  0.2191])
# 오랜 tensor([ 0.0331, -0.1919,  0.2179, -5.2273,  0.2687])
# 회 tensor([-0.0870, -0.0347,  0.2036, -6.4243,  0.0833])
# 키우다 tensor([ 0.0439, -0.2278,  0.2295, -4.8212,  0.1061])
# 불구 tensor([ 0.0770, -0.2683,  0.1877, -4.8819,  0.2246])
# 일화 tensor([ 0.0201, -0.1168,  0.2249, -5.2581,  0.1864])
# 가볍다 tensor([ 0.1320, -0.1905,  0.3008, -4.7082,  0.1465])
# 의심 tensor([ 0.1384, -0.1430,  0.3041, -4.8418,  0.2810])
# 영어 tensor([ 0.0903, -0.0087,  0.1998, -5.1461,  0.2099])
# 쓸모없다 tensor([ 0.0865, -0.0494,  0.2005, -5.1680,  0.1320])
# 형 tensor([ 0.0526,  0.0532,  0.2575, -4.5636,  0.0281])
# 반복 tensor([ 0.0088, -0.3000,  0.3028, -4.1600,  0.2251])
# 적당하다 tensor([ 0.0423, -0.1410,  0.2420, -5.4350,  0.1670])
# 지나치다 tensor([ 0.0916, -0.1648,  0.2813, -5.1651,  0.1861])
# 정확하다 tensor([ 0.1142, -0.1184,  0.2922, -5.1393,  0.2479])
# 인생 tensor([ 0.1255, -0.1385,  0.2409, -4.9711,  0.2401])
# 기다리다 tensor([ 0.0806, -0.1501,  0.2873, -5.4561,  0.2376])
# 학원 tensor([ 0.1192,  0.0427,  0.1214, -6.4220,  0.1060])
# 구체 tensor([-0.1192, -0.3502,  0.2618, -4.3852,  0.1643])
# 개 tensor([ 0.0888, -0.1162,  0.3096, -5.0320,  0.3461])
# 어떤 tensor([ 0.0271, -0.1893,  0.1681, -4.9560,  0.1863])
# 주지 tensor([ 0.0546, -0.1525,  0.3043, -4.7097,  0.1684])
# 정해지다 tensor([ 0.0097, -0.1720,  0.2877, -4.9004,  0.1549])
# 그렇다고 tensor([ 0.0464, -0.1243,  0.2946, -5.2642,  0.2089])
# 아직 tensor([ 0.0361, -0.0324,  0.0316, -4.9909,  0.1123])
# 인사 tensor([ 0.0297, -0.1330, -0.0275, -5.5595,  0.2763])
# 따라서 tensor([ 0.0566, -0.1573,  0.3367, -4.9910,  0.2059])
# 리더 tensor([-0.0157, -0.1623,  0.3563, -4.4070,  0.0960])
# 혹은 tensor([ 1.4350e-03, -1.4144e-01,  2.4715e-01, -5.0712e+00,  2.1842e-01])
# 빌리다 tensor([ 0.0251, -0.1565,  0.3102, -5.0695,  0.3336])
# 제사 tensor([ 0.0362, -0.0966,  0.2204, -5.3340,  0.1610])
# 부족하다 tensor([ 0.0365, -0.2404,  0.2470, -4.9692,  0.2546])
# 맺다 tensor([ 0.0195, -0.1207,  0.1170, -5.2541,  0.1765])
# 로는 tensor([ 0.0776, -0.1098,  0.2591, -4.7959,  0.2123])
# 적도 tensor([ 0.1002, -0.1569,  0.3000, -5.3257,  0.2102])
# 교수 tensor([-0.1731, -0.1690,  0.3584, -4.6853,  0.3363])
# 밤 tensor([ 0.0750, -0.0790,  0.2557, -5.6419,  0.0794])
# 잡다 tensor([ 0.0232, -0.2122,  0.2410, -4.6522,  0.2472])
# 남편 tensor([ 0.0569, -0.1185,  0.2065, -5.7819,  0.2497])
# 어떠하다 tensor([ 0.0649, -0.1896,  0.3567, -5.0039,  0.2915])
# 제출 tensor([-0.0167, -0.1845,  0.1960, -5.4781,  0.1863])
# 그저 tensor([ 0.1141, -0.1171,  0.2800, -5.1238,  0.1824])
# 스타일 tensor([ 0.0756, -0.1386,  0.3310, -5.4230,  0.1649])
# 실수 tensor([ 0.0694, -0.0751,  0.2774, -5.0193,  0.2069])
# 터 tensor([-0.0667,  0.1171,  0.0804, -6.3025,  0.3624])
# 일도 tensor([ 0.1318, -0.1123,  0.2745, -4.4873,  0.2578])
# 여자 tensor([ 0.2185, -0.1555,  0.1393, -4.3507,  0.1021])
# 직업 tensor([ 0.1008, -0.1953,  0.1792, -4.9750,  0.1374])
# 높다 tensor([ 0.0917, -0.0839,  0.3371, -5.0369,  0.2051])
# 기본 tensor([-0.0306, -0.2478,  0.2542, -4.9956,  0.2892])
# 별 tensor([ 0.0346, -0.0101,  0.2358, -5.3522,  0.2036])
# 존재 tensor([ 0.0364, -0.1437,  0.2700, -4.8231,  0.2000])
# 치 tensor([ 0.0216, -0.0690,  0.1508, -5.5038,  0.5289])
# 대체로 tensor([-0.0118, -0.1595,  0.2870, -5.1114,  0.3042])
# 이기도 tensor([ 0.0448,  0.1634,  0.1254, -6.1057,  0.2687])
# 배려 tensor([ 0.1222, -0.1781,  0.2882, -5.0189,  0.3499])
# 분야 tensor([ 0.1160,  0.0319,  0.1272, -6.4884,  0.1872])
# 애 tensor([ 0.0341, -0.1996, -0.0187, -4.8144,  0.2395])
# 이라서 tensor([ 0.0246, -0.1686,  0.3248, -4.7303,  0.1438])
# 려고 tensor([ 0.2266, -0.0253,  0.0580, -5.4483,  0.1644])
# 진심 tensor([ 0.1148, -0.0542,  0.2903, -4.7800,  0.2001])
# 아침 tensor([ 0.1549, -0.1273,  0.3138, -5.3421,  0.1946])
# 표정 tensor([ 0.0733, -0.2293,  0.3059, -4.4981,  0.0978])
# 들어오다 tensor([ 0.0919, -0.0895,  0.2280, -4.7740,  0.2738])
# 비교 tensor([-0.0631, -0.2570,  0.3561, -4.7002,  0.2371])
# 사다 tensor([ 0.0382, -0.1008,  0.2556, -5.1178,  0.2381])
# 그림 tensor([ 0.0248, -0.2064,  0.2250, -5.1745,  0.1612])
# 실천 tensor([ 0.0650, -0.2004,  0.3640, -4.6651,  0.2583])
# 죠 tensor([ 0.1733, -0.1112,  0.3038, -4.8685,  0.3266])
# 세 tensor([-0.0184, -0.2025,  0.1292, -5.1160,  0.2102])
# 제시 tensor([-0.0134, -0.1479,  0.3071, -5.1888,  0.1960])
# 얼굴 tensor([ 0.0318, -0.0551,  0.3115, -5.5359,  0.2078])
# 단 tensor([ 0.0360,  0.0747,  0.2034, -5.5175,  0.1670])
# 전체 tensor([-9.3921e-04, -2.2780e-01,  2.6270e-01, -4.8468e+00,  2.2325e-01])
# 당시 tensor([ 0.1172, -0.2338,  0.2345, -4.6504,  0.2498])
# 조금씩 tensor([ 0.1224, -0.1570,  0.3693, -4.3573,  0.2015])
# 적극 tensor([-0.0460, -0.4051,  0.2404, -4.5334,  0.3430])
# 힘 tensor([-1.3526e-02,  4.8112e-03,  1.1212e-01, -5.6479e+00,  2.5230e-01])
# 어필 tensor([ 0.0787, -0.0982,  0.2859, -5.3263,  0.2005])
# 묻다 tensor([ 0.0207, -0.1115,  0.3197, -4.9810,  0.2324])
# 줄다 tensor([ 0.1179,  0.0379,  0.2679, -5.8457,  0.1726])
# 주어지다 tensor([ 0.0150, -0.2006,  0.1977, -5.1278,  0.2770])
# 평가 tensor([ 0.1640, -0.1276,  0.0444, -5.8976,  0.1075])
# 일상 tensor([-0.0542, -0.1949,  0.2679, -5.1200,  0.1665])
# 얼마 tensor([ 0.0257, -0.2045,  0.2663, -4.6505,  0.2688])
# 재미있다 tensor([ 0.1240, -0.2090,  0.3089, -4.5950,  0.1655])
# 아빠 tensor([ 0.0758, -0.1497,  0.2304, -5.0707,  0.2168])
# 어디 tensor([ 0.0618, -0.1398,  0.2910, -4.7087,  0.2502])
# 기간 tensor([ 0.0824, -0.0435,  0.1508, -5.5746,  0.2609])
# 유튜브 tensor([ 0.0922, -0.1733,  0.2926, -4.7360,  0.1886])
# 도전 tensor([ 0.1158, -0.0650,  0.2589, -5.0116,  0.4092])
# 쌓이다 tensor([ 0.1197, -0.1413,  0.3213, -5.3941,  0.2606])
# 제대로 tensor([ 0.1202, -0.0499,  0.1860, -4.7486,  0.2005])
# 저런 tensor([ 0.0265, -0.2246,  0.2858, -4.2688,  0.0811])
# 취향 tensor([ 0.1203, -0.1362,  0.2983, -4.9068,  0.1721])
# 기다 tensor([ 0.1043, -0.1917,  0.2974, -4.8799,  0.2229])
# 수행 tensor([ 0.0193, -0.1950,  0.2409, -4.8238,  0.1449])
# 꾸준하다 tensor([-0.0120, -0.1583,  0.2508, -5.1173,  0.1961])
# 그동안 tensor([ 0.1401, -0.0122,  0.1690, -7.0824,  0.0488])
# 볼때 tensor([-0.0128, -0.2025,  0.2075, -4.6227,  0.1840])
# 밖 tensor([ 0.1661,  0.0918,  0.1351, -5.5841,  0.2105])
# 그러하다 tensor([ 0.0902, -0.0839,  0.2980, -5.3250,  0.2027])
# 습관 tensor([ 0.0770, -0.1669,  0.2956, -5.4746,  0.2006])
# 투자 tensor([-0.0840, -0.1515,  0.1908, -5.9116,  0.2948])
# 옛날 tensor([-0.0358, -0.2064,  0.2902, -4.9887,  0.1870])
# 많아지다 tensor([ 0.1139, -0.1663,  0.2612, -4.7715,  0.2290])
# 미안하다 tensor([ 0.1214, -0.1669,  0.3254, -4.7421,  0.1351])
# 야 tensor([ 0.1228, -0.2168,  0.3024, -4.6496,  0.0538])
# 고치다 tensor([ 0.0388, -0.1313,  0.3534, -4.7333,  0.2491])
# 당신 tensor([ 0.0399,  0.0789,  0.2240, -5.9154,  0.1939])
# 커피 tensor([ 0.1329, -0.1122,  0.2612, -4.9303,  0.1844])
# 장 tensor([-0.0155,  0.1965,  0.3255, -5.7157,  0.3457])
# 통화 tensor([-0.0567, -0.1025,  0.1832, -6.0445,  0.2569])
# 안부 tensor([ 0.0770, -0.1029,  0.2905, -4.9998,  0.1917])
# 동안 tensor([ 0.0834,  0.0096,  0.3095, -4.8151,  0.3121])
# 즉흥 tensor([-0.0680, -0.4592,  0.1287, -3.7677,  0.4257])
# 어울리다 tensor([ 0.0802, -0.1931,  0.3112, -4.4127,  0.1772])
# 정보 tensor([-0.0252,  0.1173,  0.0762, -5.3595,  0.0964])
# 이든 tensor([ 0.0890, -0.0632,  0.2293, -5.2544,  0.0638])
# 수가 tensor([ 0.2496,  0.0519,  0.1336, -4.5233,  0.1631])
# 감사하다 tensor([ 0.1448, -0.1675,  0.2591, -4.9477,  0.2714])
# 깨지다 tensor([ 0.0417, -0.0883,  0.3387, -5.0046,  0.0976])
# 바라다 tensor([-0.0459, -0.1223,  0.3568, -4.8712,  0.2019])
# 해오다 tensor([ 0.0480, -0.0702,  0.2357, -4.9033,  0.1894])
# 점수 tensor([ 0.0951, -0.0876,  0.2025, -4.8772,  0.1853])
# 주일 tensor([-0.1111, -0.1258,  0.0637, -4.9002,  0.1886])
# 부담 tensor([ 0.0566,  0.1007,  0.1775, -6.1991,  0.2271])
# 수용 tensor([ 0.0673, -0.1859,  0.3230, -4.8715,  0.1515])
# 아무리 tensor([ 0.0361, -0.1147,  0.3029, -5.0778,  0.2425])
# 가까이 tensor([ 0.0667, -0.1522,  0.1984, -5.0268,  0.0783])
# 원인 tensor([ 0.0418, -0.1237,  0.2900, -4.9086,  0.1805])
# 스럽다 tensor([ 0.1048, -0.1098,  0.1948, -6.2057,  0.1173])
# 선배 tensor([ 0.1318, -0.3036,  0.2046, -5.0788,  0.1960])
# 단순하다 tensor([ 0.1102, -0.2491,  0.4211, -4.1554,  0.1983])
# 대가 tensor([ 0.2186,  0.0163,  0.2136, -6.5048,  0.2744])
# 인가요 tensor([ 9.9314e-02,  6.5372e-04,  2.2298e-01, -5.5229e+00,  1.5366e-01])
# 전략 tensor([-3.7894e-02, -3.9232e-03,  1.5722e-01, -6.3904e+00,  2.0132e-01])
# 피곤하다 tensor([ 0.0807, -0.2174,  0.2514, -4.8975,  0.2305])
# 대치 tensor([ 0.0836, -0.1728,  0.3135, -4.9109,  0.2680])
# 떠나다 tensor([ 0.1179, -0.2156,  0.2867, -4.3261,  0.2481])
# 조율 tensor([ 0.0820, -0.1272,  0.2952, -5.4998,  0.2270])
# ...
# 초등학교 tensor([ 0.0250, -0.1518, -0.0606, -6.2613,  0.2914])
# 거들다 tensor([-0.0191, -0.1950,  0.2686, -4.4250,  0.2272])
# 지역 tensor([ 0.2740, -0.0562,  0.1813, -5.1307,  0.4044])
# 부당하다 tensor([ 0.0130, -0.1994,  0.3598, -4.8626,  0.2031])
# 과학 tensor([ 0.0134, -0.2657,  0.1703, -6.2972,  0.3183])
# 리액션 tensor([ 0.1432, -0.0705,  0.3217, -5.0491,  0.1846])
# 지시 tensor([ 0.0835, -0.2006,  0.3067, -4.7522,  0.0748])
# 담임 tensor([ 0.0876, -0.0939,  0.2277, -5.0704,  0.2913])
# 농담 tensor([ 0.0931, -0.1798,  0.3246, -5.1653,  0.1356])
# 와이프 tensor([ 0.0459,  0.1060,  0.2374, -5.3878,  0.2255])
# 거부 tensor([-0.0588, -0.2031,  0.2715, -4.9081,  0.1273])
# 한잔 tensor([ 0.1210, -0.1684,  0.4114, -5.0806,  0.2851])
# 내일 tensor([ 0.1353, -0.1733,  0.2950, -4.7646,  0.1922])
# 분석 tensor([-0.0064, -0.0414,  0.1705, -5.6677,  0.2679])
# 및 tensor([ 0.1704,  0.0642,  0.1396, -4.6904,  0.0796])
# 보다도 tensor([ 0.0717, -0.3377,  0.2984, -3.8741,  0.2581])
# 유명하다 tensor([ 0.0258, -0.1748,  0.1544, -4.8685,  0.2646])
# 온라인 tensor([ 0.0880,  0.2181,  0.1245, -5.7702,  0.1469])
# 친밀하다 tensor([ 0.0955, -0.1036,  0.1668, -4.8948,  0.0703])
# 편안하다 tensor([ 0.1087, -0.1774,  0.1941, -4.8685,  0.2364])
# 지식 tensor([ 0.2324, -0.1467,  0.2408, -5.1164,  0.2207])
# 체크 tensor([ 0.0056, -0.1606,  0.2585, -5.4452,  0.1964])
# 쯤 tensor([ 0.1771,  0.1494,  0.2317, -5.9433,  0.3762])
# 만들기 tensor([ 0.0666, -0.0821,  0.2309, -6.0645,  0.1407])
# 수술 tensor([ 5.0295e-03, -1.6154e-03,  1.7106e-01, -5.9830e+00,  6.5553e-02])
# 키 tensor([ 0.0077, -0.0618,  0.0806, -5.4264,  0.4222])
# 동의 tensor([ 0.0628, -0.0699,  0.2871, -5.2313,  0.2715])
# 물다 tensor([ 0.1318, -0.1651,  0.3293, -4.6772,  0.1747])
# 팔찌 tensor([-0.1084, -0.2665,  0.5207, -3.6106,  0.0953])
# 일기 tensor([ 0.1158, -0.0948,  0.2576, -4.8116,  0.2672])
# 자존감 tensor([ 0.0617, -0.1105,  0.2287, -4.8462,  0.2195])
# 식사 tensor([ 0.1329, -0.1349,  0.3122, -5.2833,  0.1493])
# 화분 tensor([ 0.0255, -0.2463,  0.5940, -4.1400,  0.0181])
# 월 tensor([ 0.2252, -0.1218,  0.1037, -5.0693,  0.1992])
# 등등 tensor([-0.0267, -0.1251,  0.2881, -5.4633,  0.1234])
# 마찬가지 tensor([ 0.0502, -0.0630,  0.1866, -4.8131,  0.1342])
# 만이 tensor([ 0.1127, -0.2382,  0.2431, -4.9444,  0.1757])
# ㅠㅠ tensor([ 0.0250, -0.1222,  0.3501, -5.2185,  0.2507])
# 이런저런 tensor([ 0.0451, -0.1205,  0.3867, -4.6516,  0.2143])
# 각 tensor([ 0.0588, -0.0675,  0.1324, -5.7209,  0.2225])
# 일정 tensor([ 0.1453, -0.1137,  0.3019, -5.0124,  0.1915])
# 진정 tensor([ 0.0733, -0.1656,  0.3495, -4.4248,  0.1846])
# 발견 tensor([-0.0203, -0.1724,  0.2143, -4.7826,  0.1853])
# 후배 tensor([ 0.0543, -0.1302,  0.2549, -5.2382,  0.2663])
# 번은 tensor([ 0.0196, -0.1510,  0.2126, -5.0774,  0.2245])
# 해봤다 tensor([ 0.1275, -0.1304,  0.1845, -5.2502,  0.2482])
# 동아리 tensor([ 0.0930, -0.2687,  0.3754, -4.9273,  0.1523])
# 어디가 tensor([ 0.1275, -0.0681,  0.2234, -5.1400,  0.1442])
# 반성 tensor([ 0.0765, -0.1529,  0.1934, -5.2907,  0.1400])
# 올라가다 tensor([ 0.0791, -0.0501,  0.3674, -5.0482,  0.2535])
# 업계 tensor([ 0.1267,  0.0207,  0.2358, -6.5713,  0.1275])
# 인걸 tensor([ 0.0595, -0.1920,  0.2738, -4.0238,  0.1320])
# 기울이다 tensor([-0.0663, -0.0653,  0.2045, -5.3914,  0.2175])
# 한편 tensor([ 0.0949, -0.1021,  0.2794, -4.3679,  0.1643])
# 타입 tensor([ 0.0607, -0.1090,  0.2700, -5.2086,  0.1908])
# 장소 tensor([ 0.0696, -0.0984,  0.3196, -5.2581,  0.1890])
# 살아오다 tensor([ 0.0375, -0.2528,  0.3005, -4.2476,  0.1743])
# 꾸미다 tensor([ 0.0786, -0.1608,  0.3580, -4.8192,  0.2247])
# 성과 tensor([ 0.0518,  0.0433,  0.1917, -6.1325,  0.0991])
# 공 tensor([ 0.2905, -0.0430,  0.1056, -5.5812,  0.4133])
# 테스트 tensor([-0.0071, -0.3107,  0.4614, -3.9297,  0.2004])
# 부서 tensor([-0.0169, -0.0939,  0.3260, -5.2610,  0.1692])
# 조건 tensor([ 0.1356,  0.0388,  0.0634, -5.6447,  0.2093])
# 성인 tensor([ 0.1874, -0.1145,  0.2321, -4.9429,  0.2238])
# 소통 tensor([ 0.0216, -0.0823,  0.2907, -5.3426,  0.2260])
# 언쟁 tensor([ 0.0405, -0.1270,  0.3004, -5.4882,  0.1942])
# 겨 tensor([ 0.0228, -0.0547,  0.1459, -5.7271,  0.3248])
# 구입 tensor([ 0.0434, -0.1635,  0.3572, -5.1136,  0.0153])
# 에만 tensor([ 0.1071,  0.0605,  0.1352, -6.2769,  0.2311])
# 회복 tensor([ 0.1518, -0.0979,  0.2076, -4.4573,  0.1811])
# 침대 tensor([ 0.1906, -0.1852,  0.2567, -4.6274,  0.1362])
# 공간 tensor([ 0.1040, -0.1317,  0.1504, -5.6411,  0.1050])
# 기한 tensor([ 6.9120e-02,  9.3072e-04,  3.1277e-01, -5.1213e+00,  2.0828e-01])
# 흐르다 tensor([ 0.0103, -0.1203,  0.2977, -5.2002,  0.1335])
# 초라하다 tensor([ 0.0943, -0.2711,  0.2623, -4.1989,  0.1869])
# 부터는 tensor([ 0.0956, -0.1336,  0.2850, -4.6643,  0.2886])
# 재미없다 tensor([ 0.1448, -0.1692,  0.2732, -5.7035,  0.2107])
# 숫자 tensor([ 0.1142, -0.0637,  0.3555, -5.6175,  0.2586])
# 언제나 tensor([-0.0296, -0.0114,  0.2982, -5.2476,  0.2525])
# 방안 tensor([ 0.1683, -0.0210,  0.1178, -6.2696,  0.2300])
# 끌다 tensor([ 0.0290, -0.1253,  0.4135, -4.9693,  0.2281])
# 밀리다 tensor([ 0.1794, -0.2350,  0.1959, -4.8874,  0.2651])
# 무작정 tensor([ 0.0635, -0.1829,  0.2086, -4.6904,  0.2180])
# 아마도 tensor([ 0.1257, -0.0669,  0.3543, -5.2303,  0.1798])
# 비중 tensor([ 0.0450, -0.1857,  0.1669, -4.6981,  0.2453])
# 약하다 tensor([-0.0550, -0.3315,  0.2736, -3.8942,  0.2576])
# 던지다 tensor([ 0.2418, -0.1180,  0.2971, -4.9490,  0.1671])
# 젊다 tensor([ 0.0371, -0.1150,  0.0750, -6.0408,  0.2696])
# 판매 tensor([ 0.1473, -0.0312,  0.2143, -4.9872,  0.1736])
# 감각 tensor([ 0.0353, -0.1309,  0.2739, -4.5930,  0.2160])
# 께서 tensor([ 0.1969, -0.0946,  0.1170, -6.5679,  0.1630])
# 추억 tensor([ 0.1367, -0.1383,  0.3643, -5.0128,  0.2861])
# 견디다 tensor([ 0.0066, -0.2086,  0.2862, -4.7994,  0.1798])
# 병 tensor([ 0.1961,  0.0337,  0.0251, -6.0116,  0.2393])
# 아픔 tensor([ 1.0317e-01, -4.4630e-03,  2.8332e-01, -5.5032e+00,  3.4041e-01])
# 합 tensor([ 0.0912, -0.1854,  0.0398, -5.8736,  0.1891])
# 주문 tensor([ 0.2401, -0.0990,  0.2511, -4.9373,  0.2845])
# 자녀 tensor([ 0.0617, -0.0116,  0.1320, -5.1906,  0.0959])
# 틀 tensor([ 0.2196, -0.2241,  0.1893, -6.0478,  0.2866])
# 포함 tensor([ 0.0543, -0.2766,  0.2214, -4.3563,  0.1712])
# 뚫다 tensor([ 0.0668, -0.0957,  0.1909, -4.6955,  0.3625])
# 한동안 tensor([ 0.1014, -0.1606,  0.3927, -4.4926,  0.1531])
# 만에 tensor([ 0.0374, -0.0888,  0.2586, -5.0465,  0.3641])
# 방 tensor([ 0.2927, -0.0145,  0.2853, -6.1302,  0.1695])
# 가르치다 tensor([ 0.0923, -0.1949,  0.2393, -4.4530,  0.3341])
# 좌절 tensor([ 0.1023, -0.1188,  0.3811, -4.4797,  0.1868])
# 줄어들다 tensor([ 0.0596, -0.1301,  0.1728, -4.9478,  0.0937])
# 남기다 tensor([ 0.1342, -0.2248,  0.2239, -4.0821,  0.2698])
# 일찍 tensor([ 0.0789, -0.1150,  0.3204, -5.0736,  0.1575])
# 간단하다 tensor([ 0.0900, -0.1675,  0.2699, -4.7599,  0.2981])
# 동창 tensor([ 0.0156, -0.0516,  0.1868, -5.9376,  0.2231])
# 똑같이 tensor([ 0.0071, -0.0470,  0.3444, -4.6489,  0.2933])
# 일어나서 tensor([ 0.1021, -0.3110,  0.2665, -4.8209,  0.1642])
# 상식 tensor([-0.0322, -0.2614,  0.1505, -5.0100,  0.2768])
# 사이트 tensor([-0.0963, -0.1333,  0.2449, -4.2422,  0.0251])
# 곤 tensor([ 0.2694,  0.0688,  0.3977, -4.4561,  0.3630])
# 멈추다 tensor([ 0.0861, -0.1194,  0.2598, -4.7604,  0.1025])
# 보더 tensor([ 0.1391, -0.1354,  0.1748, -5.2062,  0.2581])
# 폭발 tensor([ 0.1604, -0.2135,  0.2503, -5.2673,  0.1285])
# 소 tensor([ 7.9021e-02, -1.4421e-03,  8.1580e-03, -5.3065e+00,  1.1200e-01])
# 앞서서 tensor([ 0.0897, -0.0764,  0.1917, -5.4164,  0.2134])
# 하소연 tensor([ 0.0493, -0.1989,  0.2793, -4.6490,  0.2520])
# 무기 tensor([-0.0649, -0.2421,  0.1105, -4.8572,  0.1565])
# 노 tensor([-0.0237, -0.1329,  0.2309, -4.6213,  0.1178])
# 무리 tensor([-0.0334, -0.0666,  0.3663, -5.9603,  0.3725])
# 장난 tensor([ 0.1722, -0.1936,  0.2100, -4.8760,  0.2339])
# 놀라다 tensor([ 0.1641, -0.1859,  0.2789, -5.0457,  0.1308])
# 어머니 tensor([ 0.1602, -0.2119,  0.3180, -4.5218,  0.2706])
# 불안감 tensor([ 0.0563, -0.1587,  0.2706, -5.3075,  0.1919])
# 월급 tensor([-0.0317, -0.2333,  0.2843, -4.8457,  0.2925])
# 하고는 tensor([ 0.1538, -0.1897,  0.3794, -4.8061,  0.2387])
# 이정 tensor([ 0.0575, -0.1485,  0.1864, -5.1099,  0.1823])
# 핀잔 tensor([ 0.1886, -0.1454,  0.2228, -4.2429,  0.3222])
# 지하철 tensor([ 0.0588, -0.0580,  0.1717, -6.2534,  0.2210])
# 아쉽다 tensor([ 0.1307, -0.1862,  0.3017, -5.7306,  0.1742])
# 만들어지다 tensor([-0.0052, -0.1526,  0.3690, -4.1229,  0.2309])
# 장면 tensor([ 0.1559, -0.0812,  0.3575, -5.0656,  0.2746])
# 친한친구 tensor([ 0.0534, -0.2369,  0.3594, -4.3228,  0.1037])
# 숨기다 tensor([ 0.0402, -0.0487,  0.2676, -5.4028,  0.0859])
# 수준 tensor([ 1.3517e-03, -1.1709e-01,  3.0154e-01, -4.7383e+00,  1.7064e-01])
# 지원 tensor([ 2.1034e-01, -1.7586e-03,  1.0056e-01, -5.4189e+00,  7.6355e-02])
# 막다 tensor([ 0.0650, -0.2103,  0.1992, -4.6183,  0.3537])
# 빠져나오다 tensor([-0.0153, -0.0699,  0.2774, -5.6420,  0.2087])
# 교양 tensor([ 0.0874, -0.1621,  0.2013, -4.7405,  0.3068])
# 별다르다 tensor([ 0.0806, -0.1621,  0.3162, -4.8635,  0.1430])
# 맘 tensor([-6.8847e-03,  4.3731e-02,  1.3313e-01, -7.1699e+00,  2.8653e-01])
# 기준 tensor([ 0.1350, -0.0381,  0.1394, -5.0722,  0.0880])
# 도저히 tensor([ 0.0737, -0.0801,  0.2613, -5.5361,  0.2248])
# 삼다 tensor([ 0.0171, -0.1272,  0.3657, -4.5804,  0.0324])
# 외부 tensor([ 0.0229, -0.1221,  0.2532, -5.4376,  0.2221])
# 컨디션 tensor([ 0.1156, -0.0240,  0.1740, -5.3163,  0.2225])
# 가야 tensor([ 0.0417, -0.1160,  0.3045, -5.1514,  0.2306])
# 이직 tensor([ 0.0522, -0.1304,  0.2795, -4.6186,  0.1800])
# 효과 tensor([-5.9619e-02, -5.1541e-01,  9.6704e-04, -4.5194e+00,  3.0469e-01])
# 발 tensor([-0.0282,  0.0621,  0.1458, -5.8679,  0.1925])
# 대인 tensor([-0.0620, -0.0301,  0.1376, -5.6463,  0.0368])
# 맞장구 tensor([ 0.1297, -0.0719,  0.1577, -4.9148,  0.1997])
# 근 tensor([ 0.1128, -0.0271,  0.1044, -4.6025,  0.4312])
# 점심 tensor([-1.3595e-04, -1.5165e-01,  3.6613e-01, -5.7729e+00,  2.5897e-01])
# 대다수 tensor([ 0.1680, -0.2052,  0.2044, -4.2458,  0.1000])
# 다예 tensor([-0.2177, -0.3087,  0.2314, -5.3274,  0.5323])
# 에서의 tensor([ 0.0636, -0.0903,  0.2295, -5.1919,  0.2333])
# 아이디어 tensor([ 0.1429, -0.0426,  0.2719, -4.4038,  0.3308])
# 발전 tensor([ 0.1329,  0.0076,  0.0395, -6.6080,  0.1843])
# 하라 tensor([ 0.2680, -0.0742,  0.0480, -4.2125,  0.0340])
# 그러다가 tensor([ 0.0920, -0.1526,  0.4390, -4.6135,  0.2063])
# 소설 tensor([ 0.0449, -0.1923,  0.3952, -4.8652,  0.0215])
# 앞두다 tensor([ 0.1298, -0.0137,  0.2133, -5.5482,  0.1970])
# 오래되다 tensor([ 0.0190, -0.0484,  0.2626, -4.4570,  0.3179])
# 개발 tensor([ 0.0256, -0.0540,  0.2505, -5.0130,  0.0935])
# 뿌듯하다 tensor([ 0.0074, -0.1432,  0.1982, -4.6266,  0.2500])
# 잘해주다 tensor([ 0.0350, -0.1382,  0.3136, -5.3714,  0.1301])
# 공개 tensor([ 0.0068, -0.2401,  0.1467, -3.9146,  0.2915])
# 들리다 tensor([ 0.1051, -0.0716,  0.3018, -5.1664,  0.0886])
# 후자 tensor([ 0.0137, -0.1528,  0.2404, -5.1001,  0.0999])
# 확고하다 tensor([ 0.1909, -0.1679,  0.3201, -5.2164,  0.3068])
# 땅 tensor([-0.0109, -0.1527,  0.1178, -5.2558,  0.2634])
# 핑계 tensor([ 0.1494, -0.1595,  0.3056, -4.1375,  0.1948])
# 성공하다 tensor([ 0.0812, -0.2880,  0.2791, -4.8336,  0.0574])
# 언급 tensor([ 0.0218, -0.0148,  0.1128, -5.0739,  0.1544])
# 보장 tensor([ 0.0259,  0.0295,  0.1479, -6.1536,  0.1652])
# 규칙 tensor([ 0.2534,  0.0263, -0.0699, -4.9268,  0.1371])
# 전부 tensor([ 0.1334, -0.1758,  0.2852, -5.1081,  0.2375])
# 말투 tensor([ 0.0514, -0.1627,  0.2945, -4.3592,  0.1386])
# 공통점 tensor([ 0.0680, -0.1989,  0.3294, -4.8127,  0.3545])
# 일본어 tensor([ 0.0731, -0.0465,  0.1290, -5.0509,  0.0419])
# 지켜보다 tensor([ 0.0986, -0.1530,  0.2664, -5.7385,  0.2693])
# 공원 tensor([ 0.2790, -0.2058,  0.0543, -5.7720, -0.0146])
# 추구 tensor([ 0.0216, -0.2542,  0.2085, -4.6670,  0.1248])
# 추천 tensor([ 0.0859, -0.0530,  0.0421, -5.3376,  0.0860])
# 관리 tensor([ 0.2077, -0.2103,  0.1896, -6.0838,  0.2441])
# 하니 tensor([ 0.0745,  0.0316, -0.1809, -5.1302,  0.1477])
# 적어도 tensor([ 0.0644, -0.2292,  0.2200, -4.3743,  0.2496])
# 감량 tensor([ 0.0752, -0.0463,  0.2079, -4.8122,  0.2378])
# 어서 tensor([-0.0156, -0.2655,  0.2142, -5.5137,  0.4011])
# 소중하다 tensor([ 0.1533, -0.1417,  0.2648, -4.8752,  0.2221])
# 검색 tensor([ 0.0631,  0.1004,  0.1299, -6.2900,  0.1228])
# 살피다 tensor([ 0.1252, -0.1525,  0.3497, -4.5134,  0.2183])
# 궁금하다 tensor([-0.0529, -0.0858,  0.2277, -5.4366,  0.2173])
# 범위 tensor([ 0.1303, -0.0703,  0.2679, -5.3181,  0.3340])
# 메일 tensor([ 0.1609, -0.0640,  0.3216, -4.8499,  0.0561])
# 으로의 tensor([ 0.0221, -0.1273,  0.2375, -5.2122,  0.2950])
# 값 tensor([ 0.1456,  0.1407,  0.1257, -5.4209,  0.3500])
# 대비 tensor([ 0.2053, -0.0947,  0.0891, -5.9692,  0.1844])
# 일인 tensor([ 0.1819, -0.3332,  0.2998, -4.9256,  0.0913])
# 흐름 tensor([ 0.1675, -0.1778,  0.2300, -4.9384,  0.1403])
# 도달 tensor([-0.1396, -0.2416,  0.2364, -4.6171,  0.2143])
# 으로도 tensor([ 0.1849, -0.1059,  0.1946, -4.9487,  0.3261])
# 드러나다 tensor([ 0.1360, -0.1130,  0.3314, -4.9368,  0.0820])
# 이목 tensor([ 0.0815, -0.0697,  0.3089, -4.8379,  0.2427])
# 입 tensor([-0.0823,  0.0354,  0.0639, -5.6731,  0.1751])
# 끌 tensor([ 0.0951,  0.0133,  0.0915, -5.1171,  0.1232])
# 전화통화 tensor([ 0.0893, -0.2221,  0.4095, -4.9619,  0.1725])
# 만일 tensor([ 0.0207, -0.0159,  0.2751, -5.3761,  0.2279])
# 토론 tensor([ 0.0270, -0.1279,  0.2261, -5.1634,  0.2796])
# 특이하다 tensor([ 0.1060, -0.0589,  0.3494, -5.2168,  0.2408])
# 에게서 tensor([-1.4290e-03, -8.4468e-02,  1.3144e-01, -4.8152e+00,  1.0681e-01])
# 세다 tensor([-0.0154, -0.1232,  0.1848, -4.9157,  0.2631])
# 지도 tensor([ 0.1570, -0.0612,  0.2197, -5.6807,  0.2546])
# 친 tensor([-1.0081e-01,  4.9083e-03,  7.1242e-02, -5.0251e+00,  3.9043e-01])
# 절충 tensor([-0.0269, -0.1900,  0.0959, -4.7917,  0.2937])
# 혼란 tensor([-0.0172, -0.2690,  0.4079, -4.7296,  0.2490])
# 염려 tensor([ 0.0830, -0.1519,  0.2499, -4.8351,  0.2145])
# 몰다 tensor([ 0.2369, -0.1382,  0.2894, -4.9055,  0.2453])
# 동영상 tensor([ 0.1388, -0.0931,  0.1556, -5.5920,  0.0748])
# 딸 tensor([ 0.0809, -0.0152,  0.0974, -6.2021,  0.0976])
# 풀 tensor([ 0.1299, -0.0424,  0.2838, -4.0743,  0.0891])
# 특정 tensor([-0.0540, -0.1666,  0.4195, -3.9274,  0.3439])
# 현상 tensor([ 0.0980, -0.1927,  0.2535, -3.7905,  0.1582])
# 평범하다 tensor([ 5.5537e-03, -1.0475e-01,  1.5218e-01, -5.6332e+00,  2.6925e-01])
# 할머니 tensor([ 0.1864, -0.1972,  0.2102, -4.5583,  0.3199])
# 맡기다 tensor([ 0.0071, -0.2826,  0.3086, -4.7730,  0.1854])
# 보고서 tensor([ 0.1039, -0.0073,  0.1859, -6.7791,  0.1308])
# 쟤 tensor([ 0.0146, -0.2319,  0.2525, -4.3269,  0.1538])
# 우연히 tensor([ 0.0385, -0.0794,  0.2671, -5.2031,  0.1715])
# 은근 tensor([-0.0289, -0.2087,  0.3133, -4.3752,  0.0639])
# 저러다 tensor([ 0.0674, -0.1006,  0.2567, -4.8624,  0.1814])
# 친척 tensor([ 0.2140, -0.1707,  0.1446, -5.7312,  0.2028])
# 뭔 tensor([ 0.0519, -0.1527,  0.1917, -4.7342,  0.3027])
# 으론 tensor([-0.0346, -0.1807,  0.3636, -4.7309,  0.1858])
# 내면 tensor([ 0.0057, -0.1998,  0.4283, -4.3002,  0.2332])
# 꼬리 tensor([ 0.2045, -0.0852,  0.3752, -5.1982,  0.2909])
# 사례 tensor([ 0.0299, -0.3188,  0.4231, -5.0931,  0.2501])
# 정말로 tensor([ 0.0101, -0.1153,  0.3068, -4.9069,  0.1760])
# 함부로 tensor([ 0.1093, -0.0978,  0.3990, -4.6068,  0.2785])
# 늘리다 tensor([ 0.0079, -0.1954,  0.2370, -5.2257,  0.1129])
# 그다지 tensor([ 0.2287, -0.1203,  0.3162, -4.9133,  0.1919])
# 윗 tensor([-0.0435, -0.0883,  0.1545, -4.4504,  0.0575])
# 이어지다 tensor([ 0.0683, -0.1283,  0.2288, -5.4824,  0.2657])
# 탓 tensor([ 0.0603, -0.0120,  0.3111, -4.4159,  0.1259])
# 지점 tensor([ 0.0537, -0.1583,  0.4415, -4.7100,  0.2230])
# 주기도 tensor([ 0.2037,  0.0305,  0.2999, -5.7975,  0.2263])
# 사업 tensor([-0.0103,  0.0174,  0.2741, -6.1844, -0.0243])
# 문서 tensor([-0.0634, -0.1664,  0.2263, -4.8500,  0.2382])
# 단체 tensor([ 0.0337,  0.0356, -0.0567, -5.0681,  0.1251])
# 심리 tensor([ 0.0529, -0.2766,  0.1294, -5.0372,  0.4119])
# 살리다 tensor([ 0.0711, -0.2128,  0.3254, -3.5724,  0.2511])
# 부끄럽다 tensor([ 0.0472, -0.0700,  0.1738, -4.8203,  0.1247])
# 요소 tensor([ 0.0696, -0.1424,  0.3087, -4.9025,  0.1689])
# 낮다 tensor([ 0.0711, -0.2055,  0.3058, -4.7084,  0.2699])
# 호의 tensor([ 0.1246, -0.1883,  0.1817, -4.6837,  0.2865])
# 에겐 tensor([ 0.0390, -0.2236,  0.3143, -4.6174,  0.1915])
# 생 tensor([-0.0632,  0.0413, -0.0826, -5.8681,  0.1991])
# 매력 tensor([ 0.0702, -0.2312,  0.2441, -4.1478,  0.2205])
# 타 tensor([ 0.0242, -0.1003,  0.1946, -6.2162,  0.3661])
# 덕분 tensor([ 1.8928e-03, -2.5379e-01,  2.5506e-01, -4.4411e+00,  1.6089e-01])
# 결말 tensor([ 0.1736, -0.1155,  0.2173, -4.8152,  0.0925])
# 사진 tensor([ 0.0667, -0.0645,  0.0946, -6.1404, -0.0454])
# 이전 tensor([ 0.1956, -0.2070,  0.4588, -4.8115,  0.2169])
# 울면 tensor([ 0.1523, -0.2915,  0.2681, -4.5377,  0.0280])
# 납득 tensor([-0.1066, -0.0922,  0.2349, -5.0743,  0.2461])
# 정작 tensor([ 0.0631, -0.1363,  0.2775, -5.0785,  0.2941])
# 랑은 tensor([-0.0176, -0.3201,  0.3577, -4.3415,  0.0712])
# 안정 tensor([ 0.1211, -0.1477,  0.0305, -5.4467,  0.2630])

# %%
#1. 버트에 맞는 토크나이저를 사용하지 않았기에 기대하는 성능이 나오지 않을 수 있음
#2. 유사도 측정방식에 따른 결과 변동도 있을 수 있음
#3. 학습시 한글자를 빼고 생각하기는 어려움(fasttext도 일단 포함해서 나옴)
#4. 벡터를 낸 후 한글자를 제외하고 유사어를 찾아보기

del_vocab = []
for i in result_bert:
    if len(i) == 1:
        del_vocab.append(i)

for i in del_vocab:
    del result_bert[i]

sim_bert = {}
sim_bert_vocab = {}
for i in top_vocab:
    sim_bert[i] = []
    sim_bert_vocab[i] = []

# %%
#모든 단어들에 대해서 유사도 정리하기
from scipy.spatial.distance import cosine

for i in sim_bert:
    same_ = []
    same_vocab = []
    for j in result_bert:
        if i == j:
            continue
        same_.append(1 - cosine(result_bert[i], result_bert[j]))
        same_vocab.append(j)
    sim_bert[i] = same_
    sim_bert_vocab[i] = same_vocab
    
for i in sim_bert:
    for j in range(len(sim_bert[i])):
        for k in range(j, len(sim_bert[i])):
            
            if sim_bert[i][j] < sim_bert[i][k]:
                tmp = sim_bert[i][j]
                sim_bert[i][j] = sim_bert[i][k]
                sim_bert[i][k] = tmp
                
                tmp = sim_bert_vocab[i][j]
                sim_bert_vocab[i][j] = sim_bert_vocab[i][k]
                sim_bert_vocab[i][k] = tmp

# %%
for i in sim_bert_vocab:
    print(i, ":", sim_bert_vocab[i][:10])
# Out:
# 있다 : ['없이', '만큼', '처음', '지금', '진짜', '이지만', '최근', '밖에', '아직', '스럽다']
# 않다 : ['되다', '나다', '이야기', '많다', '주다', '싶다', '해주다', '맞추다', '생각', '자다']
# 생각 : ['없다', '행동', '되다', '이야기', '나다', '싶다', '많다', '좋다', '가다', '아니다']
# 사람 : ['지금', '만큼', '이상', '처음', '이지만', '공간', '마음', '이라도', '인지', '이라는']
# 같다 : ['좋아하다', '선호', '좋다', '없다', '아니다', '많다', '생각', '힘들다', '들다', '편하다']
# 되다 : ['않다', '많다', '해주다', '생각', '싶다', '나다', '주다', '받다', '어렵다', '되어다']
# 없다 : ['행동', '생각', '많다', '아니다', '좋다', '되다', '싶다', '가다', '들다', '이야기']
# 보다 : ['없이', '보다는', '만큼', '하지만', '결과', '처럼', '관련', '에는', '진짜', '이라도']
# 그렇다 : ['어떻다', '그냥', '얘기', '좋다', '살다', '알다', '힘들다', '많다', '나오다', '싶다']
# 하고 : ['보고', '하지만', '이라고', '치고', '보다는', '스럽다', '라고', '에는', '에서는', '에서도']
# 에서 : ['에서는', '에서도', '없이', '보다는', '하지만', '에는', '스럽게', '함께', '위로', '이지만']
# 들다 : ['많다', '없다', '생각', '좋다', '행동', '싶다', '가다', '되다', '어떻다', '싫다']
# 친구 : ['얘기', '그렇다', '부분', '좋다', '알다', '어떻다', '그냥', '그렇게', '오다', '뭔가']
# 아니다 : ['없다', '많이', '자다', '맞다', '생각', '가다', '어떻다', '행동', '많다', '항상']
# 시간 : ['상황', '기간', '과정', '방식', '공간', '만큼', '방향', '마음', '하지만', '아직']
# 이다 : ['이지만', '이며', '이라는', '이라도', '이나', '보다는', '이라고', '하지만', '인데', '거리']
# 경우 : ['적다', '일이', '부분', '않다', '경험', '되다', '이야기', '자다', '느끼다', '생각']
# 자다 : ['맞다', '많이', '너무', '먹다', '그냥', '나오다', '아니다', '같이', '서로', '어떻다']
# 에게 : ['에게는', '한테', '없이', '에도', '하지만', '에는', '진짜', '에서', '인데', '이라고']
# 의견 : ['상대방', '특별하다', '최대한', '잘못', '스스로', '정말', '옳다', '다른사람', '지인', '한번']
# 많이 : ['자다', '맞다', '아니다', '많다', '맞추다', '크게', '가다', '되다', '어떻다', '않다']
# 다른 : ['하지만', '그런', '한다는', '대한', '이라는', '보다는', '상황', '처음', '없이', '함께']
# 좋다 : ['많다', '힘들다', '가다', '없다', '행동', '되다', '생각', '싶다', '그렇다', '만나다']
# 행동 : ['없다', '생각', '많다', '좋다', '가다', '아니다', '싶다', '힘들다', '싫다', '만나다']
# 편이 : ['일이', '수용', '정도', '이유', '대화', '듣다', '피하', '느끼다', '싫다', '싶다']
# 많다 : ['되다', '좋다', '싶다', '가다', '없다', '행동', '어떻다', '않다', '많이', '생각']
# 때문 : ['받다', '않다', '되다', '부분', '나오다', '해주다', '성격', '만들다', '오다', '나다']
# 이야기 : ['않다', '생각', '나다', '대화', '맞추다', '자다', '이해', '상대방', '크게', '맞다']
# 노력 : ['해결', '되어다', '생각', '나가다', '되다', '나다', '않다', '해주다', '어렵다', '없다']
# 어떻다 : ['그냥', '그렇다', '많다', '만나다', '같이', '자다', '얘기', '아니다', '맞다', '모르다']
# 이나 : ['이라도', '이다', '이지만', '인지', '이라는', '이라', '이며', '보다는', '이라고', '이상']
# 에는 : ['에서는', '보다는', '에도', '위로', '하지만', '별로', '라는', '에만', '에서도', '스럽게']
# 느끼다 : ['되다', '듣다', '생각', '행동', '없다', '해보다', '않다', '어렵다', '경우', '많다']
# 편입 : ['누구', '편이', '일이', '수용', '이유', '참다', '대하', '경계', '찾아가다', '정도']
# 좋아하다 : ['좋다', '없다', '아니다', '행동', '많다', '가다', '어떻다', '생각', '만나다', '들다']
# 관계 : ['함께', '결과', '문제', '거리', '보다는', '피해', '하지만', '행사', '방향', '상황']
# 상황 : ['방식', '결정', '마음', '하지만', '방향', '대한', '피해', '환경', '보다는', '능력']
# 가다 : ['많다', '좋다', '싶다', '만나다', '오다', '행동', '되다', '생각', '아니다', '많이']
# 그냥 : ['어떻다', '그래서', '그렇게', '그렇다', '자다', '같이', '얘기', '그게', '그리고', '오다']
# 받다 : ['해주다', '되다', '오다', '해보다', '않다', '나오다', '얘기', '자다', '만들다', '모르다']
# 감정 : ['성향', '과제', '부분', '자신', '행동', '표현', '정말', '어떻다', '으로는', '아니다']
# 하지만 : ['보다는', '위로', '대한', '스럽게', '없이', '한다는', '결과', '특히', '에서도', '별로']
# 얘기 : ['그렇게', '그냥', '오다', '해주다', '같이', '어떻다', '자다', '모르다', '그렇다', '나오다']
# 해주다 : ['되다', '받다', '얘기', '오다', '않다', '많다', '해보다', '모르다', '좋다', '힘들다']
# 맞다 : ['자다', '많이', '너무', '아니다', '먼저', '어떻다', '크게', '이야기', '그것', '나오다']
# 일이 : ['경우', '경험', '듣다', '부분', '느끼다', '자주', '이유', '주다', '이야기', '생각']
# 대해 : ['위해', '통해', '혼자', '경우', '거기', '조금', '아니다', '일이', '부분', '많이']
# 되어다 : ['되다', '나다', '해결', '않다', '많다', '노력', '해주다', '나가다', '생각', '주다']
# 위해 : ['통해', '대해', '경우', '일이', '혼자', '않다', '주다', '경험', '맞추다', '해보다']
# 경험 : ['경우', '일이', '생각', '느끼다', '지내다', '되다', '자주', '주다', '듣다', '부분']
# 상대방 : ['이야기', '최대한', '상대', '가끔', '크다', '크게', '갈등', '맞다', '먼저', '정말']
# 정도 : ['이유', '좋다', '대화', '행동', '만나다', '없다', '아니다', '힘들다', '생각', '고민']
# 싶다 : ['많다', '되다', '가다', '생각', '않다', '없다', '좋다', '행동', '어떻다', '오다']
# 이렇다 : ['그렇다', '알다', '얘기', '살다', '좋다', '그렇게', '이렇게', '어떻다', '그냥', '해주다']
# 그렇게 : ['이렇게', '그냥', '얘기', '같이', '뭔가', '어떻다', '그래서', '먹다', '자다', '너무']
# 지금 : ['아직', '현재', '처음', '오늘', '만큼', '사실', '이지만', '하지만', '이익', '이라도']
# 이고 : ['감정', '이지', '으로는', '선호', '과제', '자체', '성향', '좋아하다', '필요하다', '직접']
# 연락 : ['만나다', '힘들다', '많다', '행동', '좋다', '되다', '가다', '알다', '중요하다', '모르다']
# 부분 : ['경우', '나오다', '받다', '얘기', '자다', '때문', '같이', '이해', '오다', '되다']
# 같이 : ['먹다', '그냥', '그리고', '그래서', '너무', '그렇게', '자다', '어떻다', '얘기', '오다']
# 서로 : ['너무', '그것', '자다', '같이', '맞다', '먼저', '다시', '갈등', '어느', '친하다']
# 너무 : ['자다', '서로', '맞다', '먼저', '같이', '그것', '그냥', '어떻다', '친하다', '많이']
# 문제 : ['관계', '결과', '상황', '진짜', '보다는', '없이', '만큼', '준비', '피해', '대한']
# 만나다 : ['가다', '많다', '어떻다', '힘들다', '좋다', '행동', '아니다', '자다', '많이', '생각']
# 까지 : ['부터', '결과', '보다는', '만큼', '대로', '함께', '과정', '에는', '없이', '피해']
# 먼저 : ['너무', '맞다', '자다', '서로', '가장', '크게', '항상', '많이', '갈등', '어느']
# 그래서 : ['그리고', '그냥', '같이', '오다', '그렇게', '얘기', '자다', '어떻다', '먹다', '해보다']
# 주변 : ['새롭다', '어떤', '여러', '가깝다', '모든', '아끼다', '원하다', '연락', '고통스럽다', '평소']
# 해보다 : ['되다', '많다', '받다', '해주다', '오다', '얘기', '느끼다', '그래서', '경우', '않다']
# 신뢰 : ['대화', '공감', '이야기', '생각', '행동', '상대방', '가끔', '누군가', '항상', '정말']
# 먹다 : ['같이', '자다', '얘기', '그냥', '그리고', '오다', '너무', '맞다', '그렇게', '그래서']
# 힘들다 : ['좋다', '많다', '만나다', '되다', '행동', '가다', '생각', '나오다', '그렇다', '해주다']
# 관심 : ['항상', '정말', '크게', '자주', '먼저', '지인', '만나다', '공감', '아니다', '최대한']
# 원하다 : ['아무', '선택', '쓸다', '새롭다', '모든', '작다', '상상', '좋다', '없다', '행동']
# 이해 : ['이야기', '자다', '생각', '대화', '공감', '나오다', '않다', '맞다', '되다', '그것']
# 어렵다 : ['되다', '않다', '느끼다', '많다', '생각', '해주다', '없다', '싶다', '주다', '이해']
# 크다 : ['크게', '거의', '이야기', '따르다', '많이', '최대한', '상대방', '먼저', '어느', '맞다']
# 거나 : ['지만', '든지', '려고', '이라고', '면서', '지는', '한테', '인지', '이지만', '인데']
# 마음 : ['위로', '상황', '방식', '보다는', '만큼', '하지만', '부담', '스럽게', '별로', '대한']
# 나다 : ['않다', '되다', '생각', '이야기', '자다', '주다', '해결', '되어다', '많다', '많이']
# 직장 : ['예전', '지인', '동료', '모임', '대인관계', '항상', '평소', '혼자', '무엇', '정말']
# 자주 : ['항상', '많이', '생각', '자다', '가다', '아니다', '나오다', '주다', '부분', '중요하다']
# 나오다 : ['자다', '되다', '어떻다', '얘기', '받다', '힘들다', '맞다', '모르다', '않다', '많이']
# 모르다 : ['얘기', '어떻다', '않다', '해주다', '나오다', '되다', '많다', '오다', '싶다', '받다']
# 자신 : ['어떻다', '그냥', '많이', '자다', '그게', '너무', '나오다', '맞다', '아니다', '정말']
# 지내다 : ['되다', '받다', '오다', '해주다', '주다', '가다', '되어다', '힘들다', '좋다', '경험']
# 업무 : ['직원', '함께', '작업', '처리', '업계', '준비', '평가', '피해', '능력', '방식']
# 그리고 : ['그래서', '같이', '그냥', '자다', '어떻다', '오다', '먹다', '많이', '만들다', '너무']
# 주다 : ['되다', '않다', '생각', '많다', '오다', '가다', '나다', '이야기', '싶다', '좋다']
# 라고 : ['이라고', '보고', '라는', '한테', '려고', '없이', '위로', '라면', '진짜', '라도']
# 표현 : ['생각', '이해', '힘들다', '얘기', '해주다', '나오다', '받다', '자다', '공감', '좋다']
# 흥미 : ['크다', '상대방', '최대한', '구분', '갑자기', '크게', '전혀', '이야기', '거의', '상대']
# 걱정 : ['생각', '없다', '이야기', '행동', '싶다', '많다', '조금', '가다', '따르다', '맞추다']
# 따르다 : ['맞추다', '많이', '생각', '이야기', '행동', '없다', '크다', '않다', '크게', '나다']
# 기분 : ['어느', '너무', '서로', '거의', '갑자기', '자다', '상대', '음식', '다시', '이야기']
# 한테 : ['진짜', '만큼', '없이', '에게', '밖에', '인데', '에게는', '능력', '라고', '에만']
# 믿다 : ['행동', '없다', '좋아하다', '싫어하다', '경계', '관심', '아니다', '만나다', '따르다', '지인']
# 읽다 : ['집중', '없다', '찾다', '행동', '한번', '좋아하다', '싫다', '좋다', '즐기다', '느끼다']
# 해결 : ['나다', '되다', '노력', '되어다', '생각', '해주다', '않다', '나가다', '주다', '어렵다']
# 가끔 : ['정말', '이야기', '최대한', '상대방', '크게', '나다', '생각', '항상', '아니다', '크다']

# %%
while True:
    control = int(input("원하는 명령을 입력하세요(1. 검색, 2. 종료) : "))
    
    if control == 1:
        key = input("유사어를 찾고싶은 단어를 입력하세요. : ")
        if not key in sim_bert_vocab:
            print(key, "는 존재하지 않는 단어입니다!")
            continue
        
        rank = int(input("원하는 출력 갯수를 입력하세요. : "))
            
        c_type = int(input("원하는 유사어 종류를 입력하세요(1. 전부, 2. 체언, 3. 용언) : "))
        if c_type == 1:
            print("기준 단어 :", key)
            cnt = 0
            for i in range(len(sim_bert_vocab[key])):
                print(cnt + 1, "순위 :", sim_bert_vocab[key][i], "/ 유사도 :", sim_bert[key][i])
                cnt += 1
                if cnt == rank:
                    break
                
            
        elif c_type == 2:
            print("기준 단어 :", key)
            cnt = 0
            for i in range(len(sim_bert_vocab[key])):
                check = True if okt.pos(sim_bert_vocab[key][i])[0][1] == 'Noun' else False
                
                if check:
                    print(cnt + 1, "순위 :", sim_bert_vocab[key][i], "/ 유사도 :", sim_bert[key][i])
                    cnt += 1
                    if cnt == rank:
                        break
                else:
                    continue
            
        else:
            print("기준 단어 :", key)
            cnt = 0
            for i in range(len(sim_bert_vocab[key])):
                check = True if okt.pos(sim_bert_vocab[key][i])[0][1] == 'Adjective' else False
                
                if check:
                    print(cnt + 1, "순위 :", sim_bert_vocab[key][i], "/ 유사도 :", sim_bert[key][i])
                    cnt += 1
                    if cnt == rank:
                        break
                else:
                    continue
                
        print()
    
    else:
        print("종료되었습니다!")
        break
# Out:
# 기준 단어 : 친구
# 1 순위 : 얘기 / 유사도 : 0.9940896034240723
# 2 순위 : 부분 / 유사도 : 0.9937894940376282
# 3 순위 : 알다 / 유사도 : 0.9935139417648315
# 4 순위 : 그냥 / 유사도 : 0.993165135383606
# 5 순위 : 뭔가 / 유사도 : 0.992441713809967
# 6 순위 : 그때 / 유사도 : 0.9923856854438782
# 7 순위 : 입장 / 유사도 : 0.9923111200332642
# 8 순위 : 고민 / 유사도 : 0.9921601414680481
# 9 순위 : 이유 / 유사도 : 0.9920479655265808
# 10 순위 : 성격 / 유사도 : 0.9918030500411987
#
# 존재하지 않는 단어입니다!
# 기준 단어 : 관계
# 1 순위 : 결과 / 유사도 : 0.9363425970077515
# 2 순위 : 문제 / 유사도 : 0.9350759983062744
# 3 순위 : 거리 / 유사도 : 0.9295734763145447
# 4 순위 : 피해 / 유사도 : 0.925989031791687
# 5 순위 : 행사 / 유사도 : 0.925125241279602
# 6 순위 : 방향 / 유사도 : 0.9247291684150696
# 7 순위 : 상황 / 유사도 : 0.9241576194763184
# 8 순위 : 인사 / 유사도 : 0.9237880706787109
# 9 순위 : 이익 / 유사도 : 0.9236040115356445
# 10 순위 : 상태 / 유사도 : 0.9223005771636963
#
# 종료되었습니다!
